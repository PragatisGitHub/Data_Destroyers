# %%
import requests
import json
import time

import pandas as pd
from datetime import timedelta
from datetime import datetime
from config import gkey

# %%
#Input the target city and state
target_city = input("Enter city & state in the format 'city,state: ")
# Out:
# Enter city & state in the format 'city,state: Sayreville, NJ

# %%
#Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# %%
#Creating the params dict with address and key
params = {"address": target_city, "key": gkey}

# %%
# Run request (Build URL using the base_url & params)
response = requests.get(base_url, params=params)
#print(response.url)

# Convert the response to JSON
city_geo = response.json()

# Extract Lat/Lng
lat = city_geo["results"][0]["geometry"]["location"]["lat"]
lng = city_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print("%s: %s, %s" % (target_city, lat, lng))

#Converting the lat & lng to string
lat = str(lat)
lng = str(lng)
# Out:
# Sayreville, NJ: 40.45940210000001, -74.360846

# %%
#https://developers.google.com/places/web-service/supported_types

#Segregated the places types into indoor and outdoor activities 
Acty_In = pd.read_excel("Resources/Indoor.xlsx")
Acty_Out = pd.read_excel("Resources/Outdoor.xlsx")

#Converting the dataframe into list
Acty_Outlist = Acty_Out["Outdoor"].tolist()
Acty_Inlist = Acty_In["Indoor"].tolist()

#Find the names and addresses of nearbyplaces in given city,state entered by the user.
#Hint: See https://developers.google.com/places/web-service/supported_types
Acty = input("Enter Outdoor or Indoor: ")

if (Acty == "Outdoor"):
    Acty = Acty_Outlist
elif (Acty == "Indoor"):
    Acty = Acty_Inlist
# Out:
# Enter Outdoor or Indoor: Indoor

# %%
#Google maps nearby places search API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# %%
place_names = []
addresses = []
for i in range(len(Acty)):
    
    target_type = Acty[i]
    #radius = 40000

# Build URL using the Google Maps API and other fields
    #target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&radius="+str(radius)+"&type="+target_type#+"&opennow"
    target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&rankby=distance"+"&type="+target_type#+"&opennow"
    #print(target_url)
# Run request
    response = requests.get(target_url)
    city_placestogo = response.json()

    counter = 1
    if city_placestogo["status"] == "ZERO_RESULTS":
        print(f'No {Acty[i]} near your place of choice')
    else:
        print(f'Bingo!!! We have found good {Acty[i]}s near your place of choice!!!')
        for item in city_placestogo["results"]:
#             place_names.append(item["name"]) 
#             addresses.append(item["vicinity"])
#             counter+=1   
            for place in place_names: 
                myplace = place
                myplace = myplace.replace(" ", "%20")
                target_url = places_url+"key="+gkey+"&input="+myplace+"&inputtype=textquery"+"&fields=formatted_address,name,rating,opening_hours"
                #print(target_url)
                response = requests.get(target_url)
                data = response.json()
                #print(data)
                try:
                    print(f'{data["candidates"][0]["name"]}')
                    print(f'{data["candidates"][0]["formatted_address"]}')
                    print(f'The rating of {data["candidates"][0]["name"]} is {data["candidates"][0]["rating"]}')
                    print(f'Is it open? {data["candidates"][0]["opening_hours"]["open_now"]}')
                except:
                    print(f'{place}')
                    print("No or incomplete information found")
                print("\n")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=aquarium
# No aquarium near your place of choice
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=art_gallery
# Bingo!!! We have found good art_gallerys near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=bakery
# Bingo!!! We have found good bakerys near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=bar
# Bingo!!! We have found good bars near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=book_store
# Bingo!!! We have found good book_stores near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=bowling_alley
# No bowling_alley near your place of choice
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=cafe
# Bingo!!! We have found good cafes near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=casino
# No casino near your place of choice
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=florist
# Bingo!!! We have found good florists near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=gym
# Bingo!!! We have found good gyms near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=library
# Bingo!!! We have found good librarys near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=lodging
# Bingo!!! We have found good lodgings near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=movie_rental
# Bingo!!! We have found good movie_rentals near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=movie_theater
# Bingo!!! We have found good movie_theaters near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=museum
# Bingo!!! We have found good museums near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=night_club
# Bingo!!! We have found good night_clubs near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=pet_store
# Bingo!!! We have found good pet_stores near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=restaurant
# Bingo!!! We have found good restaurants near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=shopping_mall
# Bingo!!! We have found good shopping_malls near your place of choice!!!
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.45940210000001,-74.360846&rankby=distance&type=spa
# Bingo!!! We have found good spas near your place of choice!!!

# %%
places_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"
for place in place_names: 
    myplace = place
    myplace = myplace.replace(" ", "%20")
    target_url = places_url+"key="+gkey+"&input="+myplace+"&inputtype=textquery"+"&fields=formatted_address,name,rating,opening_hours"
    #print(target_url)
    response = requests.get(target_url)
    data = response.json()
    #print(data)
    try:
        print(f'{data["candidates"][0]["name"]}')
        print(f'{data["candidates"][0]["formatted_address"]}')
        print(f'The rating of {data["candidates"][0]["name"]} is {data["candidates"][0]["rating"]}')
        print(f'Is it open? {data["candidates"][0]["opening_hours"]["open_now"]}')
    except:
        print(f'{place}')
        print("No or incomplete information found")
    print("\n")
# Out:
# Sayreville Recreation Department
# 167 Main St, Sayreville, NJ 08872, USA
# The rating of Sayreville Recreation Department is 4.3
# Is it open? True
#
#
# Sayreville Parks Department
# 167 Main St, Sayreville, NJ 08872, USA
# The rating of Sayreville Parks Department is 4.3
# Is it open? True
#
#
# War Memorial Park
# Martinsburg, WV 25401, USA
# War Memorial Park
# No or incomplete information found
#
#
# Blacktown International Sportspark
# Eastern Rd, Rooty Hill NSW 2766, Australia
# The rating of Blacktown International Sportspark is 4.3
# International Softball Park
# No or incomplete information found
#
#
# Boro Field MacArthur Ave. Sayerville NJ
# MacArthur Ave, Sayreville, NJ 08872, USA
# Boro Field MacArthur Ave. Sayerville NJ
# No or incomplete information found
#
#
# Cannon Park Shopping Centre
# Lynchgate House, Cannon Park, Lynchgate Rd, Coventry CV4 7EH, UK
# The rating of Cannon Park Shopping Centre is 3.9
# Is it open? True
#
#
# Causeway Park
# 781 Blakely Rd, Colchester, VT 05446, USA
# The rating of Causeway Park is 4.8
# Is it open? True
#
#
# South River Community Garden
# No or incomplete information found
#
#
# Ken Buchanan Riverfront Park
# Sayreville Blvd, Sayreville, NJ 08872, USA
# Ken Buchanan Riverfront Park
# No or incomplete information found
#
#
# Bissett's Recreation Area
# South River, NJ 08882, USA
# Bissett's Recreation Area
# No or incomplete information found
#
#
# Pacer's Field
# No or incomplete information found
#
#
# Bailey Park
# 445 Patterson Ave, Winston-Salem, NC 27101, USA
# The rating of Bailey Park is 4.6
# Is it open? True
#
#
# South River Parks & Recreation
# No or incomplete information found
#
#
# Edward A. Grekoski Park
# South River, NJ 08882, USA
# Edward A. Grekoski Park
# No or incomplete information found
#
#
# Fitzpatrick's Field
# Southside Ave, South River, NJ 08882, USA
# Fitzpatrick's Field
# No or incomplete information found
#
#
# Dailey's Pond Recreation Area
# E Prospect St, South River, NJ 08882, USA
# The rating of Dailey's Pond Recreation Area is 4.2
# Is it open? True
#
#
# Veterans Park Recreation Area
# No or incomplete information found
#
#
# Edward A. Grekoski Park
# South River, NJ 08882, USA
# Edward A. Grekoski Park
# No or incomplete information found
#
#
# South River Little League
# Burton Ave, South River, NJ 08882, USA
# The rating of South River Little League is 4.3
# South River Little League
# No or incomplete information found
#
#
# Leonardine Ave
# South River, NJ 08882, USA
# Leonardine Park
# No or incomplete information found
#
#
# Denny's Stadium
# No or incomplete information found
