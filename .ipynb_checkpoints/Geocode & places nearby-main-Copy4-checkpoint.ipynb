# %%
import requests
import json

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import openweathermapy.core as owm

from config import api_key
from config import gkey
from pprint import pprint
import datetime

# %%
#Read all the Weather csv files 
main = "Resources/Indoor_Outdoor_Weather - main.csv"
main_df = pd.read_csv(main, encoding="ISO-8859-1")
Atmosphere = "Resources/Indoor_Outdoor_Weather - Atmosphere.csv"
atmosphere_df = pd.read_csv(Atmosphere, encoding="ISO-8859-1")
Drizzle= "Resources/Indoor_Outdoor_Weather - Drizzle.csv"
drizzle_df = pd.read_csv(Drizzle, encoding="ISO-8859-1")
Rain = "Resources/Indoor_Outdoor_Weather - Rain.csv"
rain_df = pd.read_csv(Rain, encoding="ISO-8859-1")
Snow ="Resources/Indoor_Outdoor_Weather - Snow.csv"
snow_df = pd.read_csv(Snow, encoding="ISO-8859-1")

#https://developers.google.com/places/web-service/supported_types
#Read all the activities files
Acty_In = pd.read_excel("Resources/Indoor.xlsx")
Acty_Out = pd.read_excel("Resources/Outdoor.xlsx")
Acty_EveIn = pd.read_excel("Resources/EveIndoor.xlsx")
Acty_EveInOut = pd.read_excel("Resources/EveInOut.xlsx")
Acty_NightIn = pd.read_excel("Resources/NightIndoor.xlsx")
Acty_NightInOut = pd.read_excel("Resources/NightInOut.xlsx")

# %%
#Converting the actvity dataframes into list
Acty_Inlist = Acty_In["Indoor"].tolist()
Acty_Outlist = Acty_Out["Outdoor"].tolist()
Acty_EveInlist = Acty_EveIn["EveIndoor"].tolist()
Acty_EveInOutlist = Acty_EveInOut["EveInOut"].tolist()
Acty_NightInlist = Acty_NightIn["NightIndoor"].tolist()
Acty_NightInOutlist = Acty_NightInOut["NightInOut"].tolist()

# %%
#Input the target city and state
target_city = input("Enter city & state in the format 'city,state: ")
# Out:
# Enter city & state in the format 'city,state: Jersey City, NJ

# %%
#Split the input to get the city
City = target_city.split(",")[0]

#Create settings dictionary for units & appid
settings = {"units": "metric", "appid": api_key}

# %%
#Get current weather
current_weather = owm.get_current(City, **settings)
#print(f"Current weather object: {current_weather}.")

#Get weather forecast
#forecast_weather = owm.get_forecast_hourly(City, **settings)
#pprint(forecast_weather)

summary = ["name", 'weather', "main", "wind", 'clouds']
data = current_weather(*summary)
#print(f"The current weather summary is : {data}.")

currentmain = data[1][0]["main"]
#print (currentmain)

temp = data[2]['temp']
#print (temp)

humidity = data[2]['humidity']
#print (humidity)

windspeed = data[3]["speed"]
#print(windspeed)

currentdesc = data[1][0]['description']
#print (currentdesc)

# %%
Finalresult = ""
Words_of_advice = " "
 
# loop through main weather types to determine if outdoor or indoor activities
if (currentmain=="Thunderstorms") or (currentmain=="Clouds") or (currentmain=="Clear") or (currentmain=="Mist"):
    if (currentmain=="Thunderstorms"):
        print(f'Staysafe!!! {currentmain} in the {City}')
        Words_of_advice = "Staysafe!!! "+ currentmain + " in the " + City
        #print(Words_of_advice)
        Finalresult="indoor"
    else:
        Finalresult="outdoor"
else:
    if currentmain=="Rain":
    #read rain.df to find which
        for index, desctype in rain_df.iterrows():
            if currentdesc == desctype["Description"]:
                Finalresult=rain_df["Rating"][index]
    elif currentmain=="Snow" :
        #read snow.df to find which
        for index, desctype in snow_df.iterrows():
            if currentdesc == desctype["Description"]:
                Finalresult=desctype["Rating"][index]
    elif currentmain=="Drizzle" :
        #read drizzledf to find which
        for index, desctype in drizzle_df.iterrrows():
            if currentdesc == desctype["Description"]:
                Finalresult=drizzle_df["Rating"][index]
    elif currentmain=="Atmosphere" :
        #read atmospheredf to find which
        for index, desctype in atmosphere_df.iterrows():
            if currentdesc== desctype["Description"]:
                Finalresult=atmosphere_df["Rating"][index]

if Finalresult == "outdoor" or " ":
    #if(currentmain=="Clouds") or (currentmain=="Clear") or (currentmain=="Mist"):
    if  (temp<7 or temp>35):
        print(f'Better to be safe inside as it is extreme temperature {temp} outside in {City}')
        Words_of_advice = "Better to be safe inside as it is extreme temperature" + str(temp) + " outside in " + City
        #print(Words_of_advice)
        Finalresult="indoor"
    elif(windspeed>38):
        #https://en.wikipedia.org/wiki/Beaufort_scale
        print(f'Better to be safe inside as it is windy ({windspeed}) outside in {City}')
        Words_of_advice = "Better to be safe inside as it is windy " + str(windspeed) + " outside in " + City
        #print(Words_of_advice)
        Finalresult="indoor"
    elif(humidity>60): 
        print(f'Better to be inside as it is quite humid ({humidity}) outside in {City}')
        Words_of_advice  = "Better to be indoors as it is quite humid " + str(humidity) + " outside in " + City
        #print(Words_of_advice)
        Finalresult="indoor" 
    else:
        print(f'It is safe & pleasant!!! Enjoy outside in the current weather of {currentmain} sky in {City}')
        Words_of_advice = "It is safe & pleasant!!! Enjoy outside in the current weather of "+ currentmain +" in "+ City
        #print(Words_of_advice)
        Finalresult="outdoor"
#print (finalresult)
# Out:
# Better to be inside as it is quite humid (74) outside in Jersey City

# %%
now = datetime.datetime.now()
print(now)
At12= now.replace(hour=12, minute=0, second=0, microsecond=0)
At15 = now.replace(hour=15, minute=0, second=0, microsecond=0)
At18 = now.replace(hour=18, minute=0, second=0, microsecond=0)
At21 = now.replace(hour=21, minute=0, second=0, microsecond=0)
# Out:
# 2018-07-05 23:23:26.257754

# %%
Acty = Finalresult
if (Acty == "outdoor"):
    if(now < At12):
        print(Words_of_advice)
        print("It's morning, plan outdoor activities for the entire day")
        Acty = Acty_Outlist
    elif((now >= At12 and now < At15)):
        print(Words_of_advice)
        print("It's afternoon, plan outdoor activities for the day")
        Acty = Acty_Outlist
    elif((now >= At15 and now < At18)):
        print(Words_of_advice)
        print("It's evening, though you can go outdoor,however, we would suggest indoor activities for the evening as parks,zoos might be closed. We would add stadiums though, as there might be matches and campgrounds if you are adventurous!!!")
        Acty = Acty_EveInOutlist
    elif((now >= At18)):
        print(Words_of_advice)
        print("It's lovely night, though you can go outdoor,however, we would recommend indoor activities for the night,as parks,zoos are closed. We would add stadiums though, as there might be matches and campgrounds if you are adventurous!!!")
        Acty = Acty_NightInOutlist 
elif (Acty == "indoor"):        
    if(now < At12):
        print(Words_of_advice)
        print("It's morning, plan indoor activities for the entire day or stay at home & relax.")
        Acty = Acty_Inlist
    elif((now >= At12 and now < At15)):
        print(Words_of_advice)
        print("It's afternoon, plan indoor activities for the day or stay at home & relax.")
        Acty = Acty_Inlist
    elif((now >= At15 and now < At18)):
        print(Words_of_advice)
        print("It's evening, plan indoor activities for the evening or stay at home & relax.")
        Acty = Acty_EveInlist 
    elif((now >= At18)):
        print(Words_of_advice)
        print("It's night, plan indoor activities for the night or stay at home & relax.")
        Acty = Acty_NightInlist
# Out:
# Better to be indoors as it is quite humid 74 outside in Jersey City
# It's night, plan indoor activities for the night or stay at home & relax.

# %%
#Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

#Creating the params dict with address and key
params = {"address": target_city, "key": gkey}

# %%
# Run request (Build URL using the base_url & params)
response = requests.get(base_url, params=params)
#print(response.url)

# Convert the response to JSON
city_geo = response.json()

# Extract Lat/Lng
lat = city_geo["results"][0]["geometry"]["location"]["lat"]
lng = city_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print("%s: %s, %s" % (target_city, lat, lng))

#Converting the lat & lng to string
lat = str(lat)
lng = str(lng)
# Out:
# Jersey City, NJ: 40.72815749999999, -74.0776417

# %%
#Google maps nearby places search API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

places_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"

# %%
#Find the names and addresses of nearbyplaces in given city,state entered by the
#user.

type_of_place = []
place_names = []
addresses = []
rating = []
openorclose = []
for i in range(len(Acty)):
    
    target_type = Acty[i]
    radius = 50000

# Build URL using the Google Maps API and other fields
    target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&radius="+str(radius)+"&type="+target_type
    #target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&rankby=distance"+"&type="+target_type

# Run request
    response = requests.get(target_url)
    city_placestogo = response.json()
   
    if city_placestogo["status"] == "ZERO_RESULTS":
        print(f'{Acty[i].upper()} : No {Acty[i]} near your place of choice.')
        type_of_place.append(target_type)
        place_names.append("Not Available ")
        addresses.append("Not Available ")
        rating.append("Not Available ")
        openorclose.append("Not Available ")
        print("\n")
    else:
        print(f'{Acty[i].upper()} : Bingo!!! We have found good {Acty[i]}s near your place of choice.')
        count = 0
        for item in city_placestogo["results"]:
            myplace = item["name"]
            myplace = myplace.replace(" ", "%20")
            target_url = places_url+"key="+gkey+"&input="+myplace+"&inputtype=textquery"+"&fields=formatted_address,name,rating,opening_hours"
            response = requests.get(target_url)
            data = response.json()
            type_of_place.append(target_type)
            try:
                place_names.append(data["candidates"][0]["name"])
            except:
                place_names.append(item["name"])
            try:    
                addresses.append(data["candidates"][0]["formatted_address"])
            except:
                addresses.append(item["vicinity"])
            try:    
                rating.append(data["candidates"][0]["rating"])
            except:   
                rating.append(np.nan)
            try:  
                if(data["candidates"][0]["opening_hours"]["open_now"]):
                    openorclose_status = "Open"
                else:
                    openorclose_status = "Closed"
                openorclose.append(openorclose_status)
            except:
                openorclose.append("Check the opening hours on the website")
            count = count + 1
        print(f'Total {count} {Acty[i]}s are found near {City}')
        print("\n")
# Out:
# BAR : Bingo!!! We have found good bars near your place of choice.
# Total 20 bars are found near Jersey City
#
#
# CASINO : Bingo!!! We have found good casinos near your place of choice.
# Total 20 casinos are found near Jersey City
#
#
# LODGING : Bingo!!! We have found good lodgings near your place of choice.
# Total 20 lodgings are found near Jersey City
#
#
# MOVIE_RENTAL : Bingo!!! We have found good movie_rentals near your place of choice.
# Total 20 movie_rentals are found near Jersey City
#
#
# MOVIE_THEATER : Bingo!!! We have found good movie_theaters near your place of choice.
# Total 20 movie_theaters are found near Jersey City
#
#
# NIGHT_CLUB : Bingo!!! We have found good night_clubs near your place of choice.
# Total 20 night_clubs are found near Jersey City
#
#
# RESTAURANT : Bingo!!! We have found good restaurants near your place of choice.
# Total 20 restaurants are found near Jersey City

# %%
Df = pd.DataFrame({"Type":type_of_place,"Place":place_names,"Address":addresses, "Rating":rating,
                  "OpenorClose":openorclose})

# %%
Df[["Type","Place","Address","Rating","OpenorClose"]]
Df[Df["Type"] == "movie_theater"]
# Out:
#                                               Address  \
# 80               570 2nd Ave, New York, NY 10016, USA
# 81             2310 Broadway, New York, NY 10024, USA
# 82            1021 US-22, Mountainside, NJ 07092, USA
# 83                   405 NJ-3, Clifton, NJ 07014, USA
# 84              1001 3rd Ave, New York, NY 10065, USA
# 85                 55 Parsonage Road unit 390, Edison
# 86              2210 Bartow Ave, Bronx, NY 10475, USA
# 87              890 Broadway, New York, NY 10003, USA
# 88  66 Third Ave (11th St), New York, NY 10003, Un...
# 89              106 Court St, Brooklyn, NY 11201, USA
# 90          80-28 Cooper Ave, Glendale, NY 11385, USA
# 91              17 US-1, New Brunswick, NJ 08901, USA
# 92       495 Prospect Ave, West Orange, NJ 07052, USA
# 93              850 Broadway, New York, NY 10003, USA
# 94             1998 Broadway, New York, NY 10023, USA
# 95             234 W 42nd St, New York, NY 10036, USA
# 96            211-01 26th Ave, Bayside, NY 11360, USA
# 97  One Garden State Plaza Blvd, Paramus, NJ 07652...
# 98          209 W Houston St, New York, NY 10014, USA
# 99              650 Plaza Dr, Secaucus, NJ 07094, USA
#
#                                OpenorClose  \
# 80  Check the opening hours on the website
# 81  Check the opening hours on the website
# 82  Check the opening hours on the website
# 83  Check the opening hours on the website
# 84  Check the opening hours on the website
# 85  Check the opening hours on the website
# 86  Check the opening hours on the website
# 87  Check the opening hours on the website
# 88  Check the opening hours on the website
# 89                                    Open
# 90                                    Open
# 91  Check the opening hours on the website
# 92  Check the opening hours on the website
# 93                                    Open
# 94  Check the opening hours on the website
# 95  Check the opening hours on the website
# 96  Check the opening hours on the website
# 97                                  Closed
# 98  Check the opening hours on the website
# 99                                    Open
#
#                                    Place  Rating           Type
# 80                       AMC Kips Bay 15     4.4  movie_theater
# 81                     AMC 84th Street 6     4.5  movie_theater
# 82                   AMC Mountainside 10     4.2  movie_theater
# 83                AMC Clifton Commons 16     4.1  movie_theater
# 84                      Cinemas 1, 2 & 3     4.3  movie_theater
# 85             AMC DINE-IN Menlo Park 12     NaN  movie_theater
# 86               AMC Bay Plaza Cinema 13     3.9  movie_theater
# 87             AMC Loews 19th St. East 6     3.4  movie_theater
# 88                         AMC Village 7     4.4  movie_theater
# 89  United Artists Court Street 12 & RPX     3.9  movie_theater
# 90            Regal Cinemas Atlas Park 8     4.2  movie_theater
# 91            AMC Loews New Brunswick 18     4.0  movie_theater
# 92             AMC DINE-IN Essex Green 9     3.7  movie_theater
# 93         Regal Union Square Stadium 14     4.1  movie_theater
# 94           AMC Loews Lincoln Square 13     4.4  movie_theater
# 95                         AMC Empire 25     4.1  movie_theater
# 96                     AMC Bay Terrace 6     4.3  movie_theater
# 97          Westfield Garden State Plaza     4.5  movie_theater
# 98                            Film Forum     4.6  movie_theater
# 99     Kerasotes ShowPlace 14 • Secaucus     4.7  movie_theater

# %%
Dfnew = Df.reset_index()
Dfnew = Dfnew.set_index("Type")
Dfnew = Dfnew.drop("index", axis=1)
Dfnew
# Out:
#                                                       Address  \
# Type
# bar                   481 Eighth Ave, New York, NY 10001, USA
# bar                     45 W 44th St, New York, NY 10036, USA
# bar                    130 E 39th St, New York, NY 10016, USA
# bar                                       New York 12534, USA
# bar                501 Lexington Ave, New York, NY 10017, USA
# bar                     44 W 63rd St, New York, NY 10023, USA
# bar                     540 Park Ave, New York, NY 10065, USA
# bar         28 East 63rd Street, at Madison Ave, New York,...
# bar                    2688 Broadway, New York, NY 10025, USA
# bar                   1 Convent Rd, Morristown, NJ 07960, USA
# bar              30 Cutter Mill Rd, Great Neck, NY 11021, USA
# bar                     35 E 18th St, New York, NY 10003, USA
# bar         8-08 Queens Plaza S, Long Island City, NY 1110...
# bar         4200, 37 W 19th St, New York, NY 10011, United...
# bar              259 West 4th Street, New York, NY 10014, USA
# bar                                      96 2nd Ave, New York
# bar                    121 W 45th St, New York, NY 10036, USA
# bar                                  200 5th Avenue, New York
# bar                           10 Columbus Circle #3, New York
# bar                   13 St Marks Pl, New York, NY 10003, USA
# casino                810 Yonkers Ave, Yonkers, NY 10704, USA
# casino           110-00 Rockaway Blvd, Jamaica, NY 11420, USA
# casino               1356 N Broad St, Hillside, NJ 07205, USA
# casino        9B Great Meadow Ln, East Hanover, NJ 07936, USA
# casino                 255 W 34th St, New York, NY 10001, USA
# casino                     1 Spring Rock Place, Spring Valley
# casino                    Come See The World With Us, Chatham
# casino      72-11 Roosevelt Ave, Jackson Heights, NY 11372...
# casino            1601 Burroughs St, Oceanside, CA 92054, USA
# casino      411 Hackensack Ave Suite 200, Hackensack, NJ 0...
# ...                                                       ...
# night_club              99 Hudson St, New York, NY 10013, USA
# night_club             116 E 27th St, New York, NY 10016, USA
# night_club            95 Delancey St, New York, NY 10002, USA
# night_club                       6 West 25th Street, New York
# night_club                        158 Ludlow Street, New York
# night_club            459 Myrtle Ave, Brooklyn, NY 11205, USA
# night_club              131 W 3rd St, New York, NY 10012, USA
# night_club      6007 Dean Martin Dr, Las Vegas, NV 89118, USA
# night_club       26 Little W 12th St, New York, NY 10014, USA
# night_club               18 Little West 12th Street, New York
# restaurant            481 Eighth Ave, New York, NY 10001, USA
# restaurant              45 W 44th St, New York, NY 10036, USA
# restaurant           228 Duffield St, Brooklyn, NY 11201, USA
# restaurant                                New York 12534, USA
# restaurant              540 Park Ave, New York, NY 10065, USA
# restaurant  28 East 63rd Street, at Madison Ave, New York,...
# restaurant              25 E 77th St, New York, NY 10075, USA
# restaurant                145 Dean Dr, Tenafly, NJ 07670, USA
# restaurant            1 Convent Rd, Morristown, NJ 07960, USA
# restaurant       30 Cutter Mill Rd, Great Neck, NY 11021, USA
# restaurant     369 Old Country Rd, Carle Place, NY 11514, USA
# restaurant                      366 Columbus Avenue, New York
# restaurant              35 E 18th St, New York, NY 10003, USA
# restaurant  8-08 Queens Plaza S, Long Island City, NY 1110...
# restaurant          88 Riverside Ave, Red Bank, NJ 07701, USA
# restaurant           2 Lexington Ave, New York, NY 10010, USA
# restaurant       259 West 4th Street, New York, NY 10014, USA
# restaurant           225 US-202, Basking Ridge, NJ 07920, USA
# restaurant      3998 Brush Hollow Rd, Westbury, NY 11590, USA
# restaurant                               96 2nd Ave, New York
#
#                                        OpenorClose  \
# Type
# bar                                           Open
# bar                                           Open
# bar                                           Open
# bar         Check the opening hours on the website
# bar                                           Open
# bar                                           Open
# bar                                           Open
# bar                                           Open
# bar                                           Open
# bar                                           Open
# bar                                           Open
# bar                                         Closed
# bar                                         Closed
# bar                                           Open
# bar                                           Open
# bar         Check the opening hours on the website
# bar                                           Open
# bar         Check the opening hours on the website
# bar         Check the opening hours on the website
# bar                                           Open
# casino                                        Open
# casino                                        Open
# casino                                      Closed
# casino                                      Closed
# casino      Check the opening hours on the website
# casino      Check the opening hours on the website
# casino      Check the opening hours on the website
# casino                                      Closed
# casino      Check the opening hours on the website
# casino                                      Closed
# ...                                            ...
# night_club                                    Open
# night_club                                  Closed
# night_club                                  Closed
# night_club  Check the opening hours on the website
# night_club  Check the opening hours on the website
# night_club                                    Open
# night_club  Check the opening hours on the website
# night_club                                    Open
# night_club                                    Open
# night_club  Check the opening hours on the website
# restaurant                                    Open
# restaurant                                    Open
# restaurant  Check the opening hours on the website
# restaurant  Check the opening hours on the website
# restaurant                                    Open
# restaurant                                    Open
# restaurant                                    Open
# restaurant                                    Open
# restaurant                                    Open
# restaurant                                    Open
# restaurant                                    Open
# restaurant  Check the opening hours on the website
# restaurant                                  Closed
# restaurant                                  Closed
# restaurant  Check the opening hours on the website
# restaurant                                  Closed
# restaurant                                    Open
# restaurant                                    Open
# restaurant                                    Open
# restaurant  Check the opening hours on the website
#
#                                                         Place  Rating
# Type
# bar                                        Tick Tock Diner NY     3.6
# bar                                          Sofitel New York     4.4
# bar                              The Court - A St Giles Hotel     3.7
# bar                                                    Hudson     0.0
# bar                                         Roger Smith Hotel     4.2
# bar                                          The Empire Hotel     3.9
# bar                                    Loews Regency New York     4.4
# bar                                          The Lowell Hotel     4.5
# bar                                       Marrakech Hotel-NYC     3.3
# bar                          The Madison Hotel Morristown, NJ     4.4
# bar                                         Inn At Great Neck     4.2
# bar                                               ABC Kitchen     4.4
# bar                                      Penthouse808 Rooftop     3.9
# bar                                           Flatiron Lounge     4.4
# bar                                              Extra Virgin     4.2
# bar                                           The Mermaid Inn     0.0
# bar                               Connolly's Pub & Restaurant     4.3
# bar                                                     Manzo     0.0
# bar                                                  Landmarc     0.0
# bar                                          Spot Dessert Bar     4.5
# casino                                     Empire City Casino     3.9
# casino                     Resorts World Casino New York City     3.7
# casino                               Route 22 Limousine Corp.     3.0
# casino                          Events Plus Entertainment LLC     5.0
# casino                                  Caesars World Resorts     3.4
# casino                                     Bob Mann Tours Inc     0.0
# casino                         Travel Planners of Chatham LLC     0.0
# casino                                              BELLOZINO     4.5
# casino                                    ARC Marketing, Inc.     0.0
# casino                                 KioXatm Solutions, LLC     0.0
# ...                                                       ...     ...
# night_club                                   Tamarind Tribeca     4.4
# night_club                                      Jazz Standard     4.6
# night_club                                             The DL     3.7
# night_club                                     The 40/40 Club     0.0
# night_club                                             Pianos     0.0
# night_club                                Five Spot Soul Food     3.5
# night_club                                          Blue Note     4.3
# night_club  Larry Flynt's Hustler Club - Las Vegas Strip Club     4.2
# night_club                                       STK Downtown     4.0
# night_club                                              Cielo     0.0
# restaurant                                 Tick Tock Diner NY     3.6
# restaurant                                   Sofitel New York     4.4
# restaurant                   Sheraton Brooklyn New York Hotel     3.9
# restaurant                                             Hudson     0.0
# restaurant                             Loews Regency New York     4.4
# restaurant                                   The Lowell Hotel     4.5
# restaurant                                     The Mark Hotel     4.6
# restaurant                   Clinton Inn Hotel & Event Center     3.9
# restaurant                   The Madison Hotel Morristown, NJ     4.4
# restaurant                                  Inn At Great Neck     4.2
# restaurant                 Holiday Inn Westbury - Long Island     3.8
# restaurant                                        Shake Shack     0.0
# restaurant                                        ABC Kitchen     4.4
# restaurant                               Penthouse808 Rooftop     3.9
# restaurant                              The Molly Pitcher Inn     4.3
# restaurant                                           Maialino     4.4
# restaurant                                       Extra Virgin     4.2
# restaurant                                      Olde Mill Inn     4.4
# restaurant                                Viana Hotel and Spa     4.4
# restaurant                                    The Mermaid Inn     0.0
#
# [140 rows x 4 columns]

# %%
Df.fillna(0, inplace=True)
Df1 = Df[Df["Type"] == "bar"]
x_axis = np.arange(len(Df1["Place"]))
#print(x_axis)
# x_ticks = Df1["Place"]
# x_ticks

# Y = [1.2,3.4,5.6,7.8,0.0,1.2,6.3,2.8,1.1,7]
plt.bar(x_axis, Df1["Rating"],color="b",alpha = 0.5,align="center")
plt.xticks(x_axis, Df1["Place"],rotation=45)
plt.show()
#en(Df1["Rating"])

# %%
Df.fillna(0, inplace=True)

dict={}

for item in Acty:
    item_Df = Df[Df["Type"]==item].reset_index()
    item_Df = item_Df.drop("index",1)       
    dict[item] = item_Df
    print(type(dict[item]))
    print(dict[item][["Place","Rating"]])
    print(dict[item]["Place"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                Place  Rating
# 0                 Tick Tock Diner NY     3.6
# 1                   Sofitel New York     4.4
# 2       The Court - A St Giles Hotel     3.7
# 3                             Hudson     0.0
# 4                  Roger Smith Hotel     4.2
# 5                   The Empire Hotel     3.9
# 6             Loews Regency New York     4.4
# 7                   The Lowell Hotel     4.5
# 8                Marrakech Hotel-NYC     3.3
# 9   The Madison Hotel Morristown, NJ     4.4
# 10                 Inn At Great Neck     4.2
# 11                       ABC Kitchen     4.4
# 12              Penthouse808 Rooftop     3.9
# 13                   Flatiron Lounge     4.4
# 14                      Extra Virgin     4.2
# 15                   The Mermaid Inn     0.0
# 16       Connolly's Pub & Restaurant     4.3
# 17                             Manzo     0.0
# 18                          Landmarc     0.0
# 19                  Spot Dessert Bar     4.5
# 0                   Tick Tock Diner NY
# 1                     Sofitel New York
# 2         The Court - A St Giles Hotel
# 3                               Hudson
# 4                    Roger Smith Hotel
# 5                     The Empire Hotel
# 6               Loews Regency New York
# 7                     The Lowell Hotel
# 8                  Marrakech Hotel-NYC
# 9     The Madison Hotel Morristown, NJ
# 10                   Inn At Great Neck
# 11                         ABC Kitchen
# 12                Penthouse808 Rooftop
# 13                     Flatiron Lounge
# 14                        Extra Virgin
# 15                     The Mermaid Inn
# 16         Connolly's Pub & Restaurant
# 17                               Manzo
# 18                            Landmarc
# 19                    Spot Dessert Bar
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                  Place  Rating
# 0                   Empire City Casino     3.9
# 1   Resorts World Casino New York City     3.7
# 2             Route 22 Limousine Corp.     3.0
# 3        Events Plus Entertainment LLC     5.0
# 4                Caesars World Resorts     3.4
# 5                   Bob Mann Tours Inc     0.0
# 6       Travel Planners of Chatham LLC     0.0
# 7                            BELLOZINO     4.5
# 8                  ARC Marketing, Inc.     0.0
# 9               KioXatm Solutions, LLC     0.0
# 10                           紐約市雲頂世界賭場     3.3
# 11                Gaimari Gaming Group     0.0
# 12      Great Neck Games & Productions     4.0
# 13                     Skylinegetaways     0.0
# 14                   Wow Entertainment     0.0
# 15                      Casinos By M&M     0.0
# 16            American Cruise & Travel     0.0
# 17                   Ace Deuce Casinos     0.0
# 18                   Palm Casino's USA     2.7
# 19                          GameCo Inc     0.0
# 0                     Empire City Casino
# 1     Resorts World Casino New York City
# 2               Route 22 Limousine Corp.
# 3          Events Plus Entertainment LLC
# 4                  Caesars World Resorts
# 5                     Bob Mann Tours Inc
# 6         Travel Planners of Chatham LLC
# 7                              BELLOZINO
# 8                    ARC Marketing, Inc.
# 9                 KioXatm Solutions, LLC
# 10                             紐約市雲頂世界賭場
# 11                  Gaimari Gaming Group
# 12        Great Neck Games & Productions
# 13                       Skylinegetaways
# 14                     Wow Entertainment
# 15                        Casinos By M&M
# 16              American Cruise & Travel
# 17                     Ace Deuce Casinos
# 18                     Palm Casino's USA
# 19                            GameCo Inc
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                                 Place  Rating
# 0                                  Hotel Pennsylvania     2.8
# 1                                   Royalton New York     4.1
# 2                       Ramada by Wyndham Jersey City     3.7
# 3                                   The Holland Hotel     4.1
# 4     DoubleTree by Hilton Hotel & Suites Jersey City     0.0
# 5                      The Westin Jersey City Newport     4.4
# 6                                         Econo Lodge     0.0
# 7           Courtyard by Marriott Jersey City Newport     4.2
# 8                       Candlewood Suites Jersey City     4.1
# 9             Hyatt Regency Jersey City on the Hudson     4.4
# 10                                     Quality Suites     0.0
# 11             Howard Johnson by Wyndham North Bergen     3.0
# 12           Candlewood Suites Secaucus - Meadowlands     4.2
# 13                                    Conrad New York     4.6
# 14                      Sheraton Lincoln Harbor Hotel     4.1
# 15                         New York Marriott Downtown     4.3
# 16            Club Quarters Hotel, World Trade Center     4.4
# 17                                The Greenwich Hotel     4.6
# 18                              W New York – Downtown     4.3
# 19  Holiday Inn Express North Bergen - Lincoln Tunnel     3.7
# 0                                    Hotel Pennsylvania
# 1                                     Royalton New York
# 2                         Ramada by Wyndham Jersey City
# 3                                     The Holland Hotel
# 4       DoubleTree by Hilton Hotel & Suites Jersey City
# 5                        The Westin Jersey City Newport
# 6                                           Econo Lodge
# 7             Courtyard by Marriott Jersey City Newport
# 8                         Candlewood Suites Jersey City
# 9               Hyatt Regency Jersey City on the Hudson
# 10                                       Quality Suites
# 11               Howard Johnson by Wyndham North Bergen
# 12             Candlewood Suites Secaucus - Meadowlands
# 13                                      Conrad New York
# 14                        Sheraton Lincoln Harbor Hotel
# 15                           New York Marriott Downtown
# 16              Club Quarters Hotel, World Trade Center
# 17                                  The Greenwich Hotel
# 18                                W New York – Downtown
# 19    Holiday Inn Express North Bergen - Lincoln Tunnel
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                    Place  Rating
# 0                      Westsider Records     4.0
# 1                  Academy Records & CDs     4.2
# 2   State Supply Equipment & Props, Inc.     4.2
# 3                                 Redbox     0.0
# 4           Video Network Communications     0.0
# 5                      Playtime Boutique     3.2
# 6                                 Redbox     0.0
# 7                 Majors Records & Video     3.9
# 8           Communitek Video Systems Inc     0.0
# 9                       Murder To Go Inc     0.0
# 10                              HQ Video     0.0
# 11                                Redbox     0.0
# 12                                Redbox     0.0
# 13                 Champion Stamp Co Inc     4.6
# 14                                Redbox     0.0
# 15                                Redbox     0.0
# 16                                   FYE     0.0
# 17                    Eros Entertainment     0.0
# 18              Once In A Lifetime Video     0.0
# 19                     We Deliver Videos     5.0
# 0                        Westsider Records
# 1                    Academy Records & CDs
# 2     State Supply Equipment & Props, Inc.
# 3                                   Redbox
# 4             Video Network Communications
# 5                        Playtime Boutique
# 6                                   Redbox
# 7                   Majors Records & Video
# 8             Communitek Video Systems Inc
# 9                         Murder To Go Inc
# 10                                HQ Video
# 11                                  Redbox
# 12                                  Redbox
# 13                   Champion Stamp Co Inc
# 14                                  Redbox
# 15                                  Redbox
# 16                                     FYE
# 17                      Eros Entertainment
# 18                Once In A Lifetime Video
# 19                       We Deliver Videos
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                    Place  Rating
# 0                        AMC Kips Bay 15     4.4
# 1                      AMC 84th Street 6     4.5
# 2                    AMC Mountainside 10     4.2
# 3                 AMC Clifton Commons 16     4.1
# 4                       Cinemas 1, 2 & 3     4.3
# 5              AMC DINE-IN Menlo Park 12     0.0
# 6                AMC Bay Plaza Cinema 13     3.9
# 7              AMC Loews 19th St. East 6     3.4
# 8                          AMC Village 7     4.4
# 9   United Artists Court Street 12 & RPX     3.9
# 10            Regal Cinemas Atlas Park 8     4.2
# 11            AMC Loews New Brunswick 18     4.0
# 12             AMC DINE-IN Essex Green 9     3.7
# 13         Regal Union Square Stadium 14     4.1
# 14           AMC Loews Lincoln Square 13     4.4
# 15                         AMC Empire 25     4.1
# 16                     AMC Bay Terrace 6     4.3
# 17          Westfield Garden State Plaza     4.5
# 18                            Film Forum     4.6
# 19     Kerasotes ShowPlace 14 • Secaucus     4.7
# 0                          AMC Kips Bay 15
# 1                        AMC 84th Street 6
# 2                      AMC Mountainside 10
# 3                   AMC Clifton Commons 16
# 4                         Cinemas 1, 2 & 3
# 5                AMC DINE-IN Menlo Park 12
# 6                  AMC Bay Plaza Cinema 13
# 7                AMC Loews 19th St. East 6
# 8                            AMC Village 7
# 9     United Artists Court Street 12 & RPX
# 10              Regal Cinemas Atlas Park 8
# 11              AMC Loews New Brunswick 18
# 12               AMC DINE-IN Essex Green 9
# 13           Regal Union Square Stadium 14
# 14             AMC Loews Lincoln Square 13
# 15                           AMC Empire 25
# 16                       AMC Bay Terrace 6
# 17            Westfield Garden State Plaza
# 18                              Film Forum
# 19       Kerasotes ShowPlace 14 • Secaucus
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                                 Place  Rating
# 0                                              Hudson     0.0
# 1                                    The Empire Hotel     3.9
# 2                              Loews Regency New York     4.4
# 3                                    The Lowell Hotel     4.5
# 4                                 Marrakech Hotel-NYC     3.3
# 5                                   Inn At Great Neck     4.2
# 6                                Penthouse808 Rooftop     3.9
# 7                                     Flatiron Lounge     4.4
# 8                              Lucky Strike Manhattan     4.1
# 9                                           48 Lounge     4.2
# 10                                   Tamarind Tribeca     4.4
# 11                                      Jazz Standard     4.6
# 12                                             The DL     3.7
# 13                                     The 40/40 Club     0.0
# 14                                             Pianos     0.0
# 15                                Five Spot Soul Food     3.5
# 16                                          Blue Note     4.3
# 17  Larry Flynt's Hustler Club - Las Vegas Strip Club     4.2
# 18                                       STK Downtown     4.0
# 19                                              Cielo     0.0
# 0                                                Hudson
# 1                                      The Empire Hotel
# 2                                Loews Regency New York
# 3                                      The Lowell Hotel
# 4                                   Marrakech Hotel-NYC
# 5                                     Inn At Great Neck
# 6                                  Penthouse808 Rooftop
# 7                                       Flatiron Lounge
# 8                                Lucky Strike Manhattan
# 9                                             48 Lounge
# 10                                     Tamarind Tribeca
# 11                                        Jazz Standard
# 12                                               The DL
# 13                                       The 40/40 Club
# 14                                               Pianos
# 15                                  Five Spot Soul Food
# 16                                            Blue Note
# 17    Larry Flynt's Hustler Club - Las Vegas Strip Club
# 18                                         STK Downtown
# 19                                                Cielo
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                  Place  Rating
# 0                   Tick Tock Diner NY     3.6
# 1                     Sofitel New York     4.4
# 2     Sheraton Brooklyn New York Hotel     3.9
# 3                               Hudson     0.0
# 4               Loews Regency New York     4.4
# 5                     The Lowell Hotel     4.5
# 6                       The Mark Hotel     4.6
# 7     Clinton Inn Hotel & Event Center     3.9
# 8     The Madison Hotel Morristown, NJ     4.4
# 9                    Inn At Great Neck     4.2
# 10  Holiday Inn Westbury - Long Island     3.8
# 11                         Shake Shack     0.0
# 12                         ABC Kitchen     4.4
# 13                Penthouse808 Rooftop     3.9
# 14               The Molly Pitcher Inn     4.3
# 15                            Maialino     4.4
# 16                        Extra Virgin     4.2
# 17                       Olde Mill Inn     4.4
# 18                 Viana Hotel and Spa     4.4
# 19                     The Mermaid Inn     0.0
# 0                     Tick Tock Diner NY
# 1                       Sofitel New York
# 2       Sheraton Brooklyn New York Hotel
# 3                                 Hudson
# 4                 Loews Regency New York
# 5                       The Lowell Hotel
# 6                         The Mark Hotel
# 7       Clinton Inn Hotel & Event Center
# 8       The Madison Hotel Morristown, NJ
# 9                      Inn At Great Neck
# 10    Holiday Inn Westbury - Long Island
# 11                           Shake Shack
# 12                           ABC Kitchen
# 13                  Penthouse808 Rooftop
# 14                 The Molly Pitcher Inn
# 15                              Maialino
# 16                          Extra Virgin
# 17                         Olde Mill Inn
# 18                   Viana Hotel and Spa
# 19                       The Mermaid Inn
# Name: Place, dtype: object
