# %%
import requests
import json

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import openweathermapy.core as owm

from config import api_key
from config import gkey
from pprint import pprint
import datetime

# %%
#Read all the Weather csv files 
main = "Resources/Indoor_Outdoor_Weather - main.csv"
main_df = pd.read_csv(main, encoding="ISO-8859-1")
Atmosphere = "Resources/Indoor_Outdoor_Weather - Atmosphere.csv"
atmosphere_df = pd.read_csv(Atmosphere, encoding="ISO-8859-1")
Drizzle= "Resources/Indoor_Outdoor_Weather - Drizzle.csv"
drizzle_df = pd.read_csv(Drizzle, encoding="ISO-8859-1")
Rain = "Resources/Indoor_Outdoor_Weather - Rain.csv"
rain_df = pd.read_csv(Rain, encoding="ISO-8859-1")
Snow ="Resources/Indoor_Outdoor_Weather - Snow.csv"
snow_df = pd.read_csv(Snow, encoding="ISO-8859-1")

#https://developers.google.com/places/web-service/supported_types
#Read all the activities files
Acty_In = pd.read_excel("Resources/Indoor.xlsx")
Acty_Out = pd.read_excel("Resources/Outdoor.xlsx")
Acty_EveIn = pd.read_excel("Resources/EveIndoor.xlsx")
Acty_EveInOut = pd.read_excel("Resources/EveInOut.xlsx")
Acty_NightIn = pd.read_excel("Resources/NightIndoor.xlsx")
Acty_NightInOut = pd.read_excel("Resources/NightInOut.xlsx")

# %%
#Converting the actvity dataframes into list
Acty_Inlist = Acty_In["Indoor"].tolist()
Acty_Outlist = Acty_Out["Outdoor"].tolist()
Acty_EveInlist = Acty_EveIn["EveIndoor"].tolist()
Acty_EveInOutlist = Acty_EveInOut["EveInOut"].tolist()
Acty_NightInlist = Acty_NightIn["NightIndoor"].tolist()
Acty_NightInOutlist = Acty_NightInOut["NightInOut"].tolist()

# %%
#Input the target city and state
target_city = input("Enter city & state in the format 'city,state: ")
# Out:
# Enter city & state in the format 'city,state: East Brunswick, NJ

# %%
#Split the input to get the city
City = target_city.split(",")[0]

#Create settings dictionary for units & appid
settings = {"units": "metric", "appid": api_key}

# %%
#Get current weather
current_weather = owm.get_current(City, **settings)
#print(f"Current weather object: {current_weather}.")

#Get weather forecast
#forecast_weather = owm.get_forecast_hourly(City, **settings)
#pprint(forecast_weather)

summary = ["name", 'weather', "main", "wind", 'clouds']
data = current_weather(*summary)
#print(f"The current weather summary is : {data}.")

currentmain = data[1][0]["main"]
#print (currentmain)

temp = data[2]['temp']
#print (temp)

humidity = data[2]['humidity']
#print (humidity)

windspeed = data[3]["speed"]
#print(windspeed)

currentdesc = data[1][0]['description']
#print (currentdesc)

# %%
Finalresult = ""
Words_of_advice = " "
 
# loop through main weather types to determine if outdoor or indoor activities
if (currentmain=="Thunderstorms") or (currentmain=="Clouds") or (currentmain=="Clear") or (currentmain=="Mist"):
    if (currentmain=="Thunderstorms"):
        print(f'Staysafe!!! {currentmain} in the {City}')
        Words_of_advice = "Staysafe!!! "+ currentmain + " in the " + City
        #print(Words_of_advice)
        Finalresult="indoor"
    else:
        Finalresult="outdoor"
else:
    if currentmain=="Rain":
    #read rain.df to find which
        for index, desctype in rain_df.iterrows():
            if currentdesc == desctype["Description"]:
                Finalresult=rain_df["Rating"][index]
    elif currentmain=="Snow" :
        #read snow.df to find which
        for index, desctype in snow_df.iterrows():
            if currentdesc == desctype["Description"]:
                Finalresult=desctype["Rating"][index]
    elif currentmain=="Drizzle" :
        #read drizzledf to find which
        for index, desctype in drizzle_df.iterrrows():
            if currentdesc == desctype["Description"]:
                Finalresult=drizzle_df["Rating"][index]
    elif currentmain=="Atmosphere" :
        #read atmospheredf to find which
        for index, desctype in atmosphere_df.iterrows():
            if currentdesc== desctype["Description"]:
                Finalresult=atmosphere_df["Rating"][index]

if Finalresult == "outdoor" or " ":
    #if(currentmain=="Clouds") or (currentmain=="Clear") or (currentmain=="Mist"):
    if  (temp<7 or temp>35):
        print(f'Better to be safe inside as it is extreme temperature {temp} outside in {City}')
        Words_of_advice = "Better to be safe inside as it is extreme temperature" + str(temp) + " outside in " + City
        #print(Words_of_advice)
        Finalresult="indoor"
    elif(windspeed>38):
        #https://en.wikipedia.org/wiki/Beaufort_scale
        print(f'Better to be safe inside as it is windy ({windspeed}) outside in {City}')
        Words_of_advice = "Better to be safe inside as it is windy " + str(windspeed) + " outside in " + City
        #print(Words_of_advice)
        Finalresult="indoor"
    elif(humidity>60): 
        print(f'Better to be inside as it is quite humid ({humidity}) outside in {City}')
        Words_of_advice  = "Better to be indoors as it is quite humid " + str(humidity) + " outside in " + City
        #print(Words_of_advice)
        Finalresult="indoor" 
    else:
        print(f'It is safe & pleasant!!! Enjoy outside in the current weather of {currentmain} sky in {City}')
        Words_of_advice = "It is safe & pleasant!!! Enjoy outside in the current weather of "+ currentmain +" in "+ City
        #print(Words_of_advice)
        Finalresult="outdoor"
#print (finalresult)
# Out:
# Better to be inside as it is quite humid (70) outside in East Brunswick

# %%
now = datetime.datetime.now()
print(now)
At12= now.replace(hour=12, minute=0, second=0, microsecond=0)
At15 = now.replace(hour=15, minute=0, second=0, microsecond=0)
At18 = now.replace(hour=18, minute=0, second=0, microsecond=0)
At21 = now.replace(hour=21, minute=0, second=0, microsecond=0)
# Out:
# 2018-07-05 21:51:12.451149

# %%
Acty = Finalresult
if (Acty == "outdoor"):
    if(now < At12):
        print(Words_of_advice)
        print("It's morning, plan outdoor activities for the entire day")
        Acty = Acty_Outlist
    elif((now >= At12 and now < At15)):
        print(Words_of_advice)
        print("It's afternoon, plan outdoor activities for the day")
        Acty = Acty_Outlist
    elif((now >= At15 and now < At18)):
        print(Words_of_advice)
        print("It's evening, though you can go outdoor,however, we would suggest indoor activities for the evening as parks,zoos might be closed. We would add stadiums though, as there might be matches and campgrounds if you are adventurous!!!")
        Acty = Acty_EveInOutlist
    elif((now >= At18)):
        print(Words_of_advice)
        print("It's lovely night, though you can go outdoor,however, we would recommend indoor activities for the night,as parks,zoos are closed. We would add stadiums though, as there might be matches and campgrounds if you are adventurous!!!")
        Acty = Acty_NightInOutlist 
elif (Acty == "indoor"):        
    if(now < At12):
        print(Words_of_advice)
        print("It's morning, plan indoor activities for the entire day or stay at home & relax.")
        Acty = Acty_Inlist
    elif((now >= At12 and now < At15)):
        print(Words_of_advice)
        print("It's afternoon, plan indoor activities for the day or stay at home & relax.")
        Acty = Acty_Inlist
    elif((now >= At15 and now < At18)):
        print(Words_of_advice)
        print("It's evening, plan indoor activities for the evening or stay at home & relax.")
        Acty = Acty_EveInlist 
    elif((now >= At18)):
        print(Words_of_advice)
        print("It's night, plan indoor activities for the night or stay at home & relax.")
        Acty = Acty_NightInlist
# Out:
# Better to be indoors as it is quite humid 70 outside in East Brunswick
# It's night, plan indoor activities for the night or stay at home & relax.

# %%
#Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

#Creating the params dict with address and key
params = {"address": target_city, "key": gkey}

# %%
# Run request (Build URL using the base_url & params)
response = requests.get(base_url, params=params)
#print(response.url)

# Convert the response to JSON
city_geo = response.json()

# Extract Lat/Lng
lat = city_geo["results"][0]["geometry"]["location"]["lat"]
lng = city_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print("%s: %s, %s" % (target_city, lat, lng))

#Converting the lat & lng to string
lat = str(lat)
lng = str(lng)
# Out:
# East Brunswick, NJ: 40.4316955, -74.4049778

# %%
#Google maps nearby places search API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

places_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"

# %%
#Find the names and addresses of nearbyplaces in given city,state entered by the
#user.

type_of_place = []
place_names = []
addresses = []
rating = []
openorclose = []
#Noinfo = []
for i in range(len(Acty)):
    
    target_type = Acty[i]
    radius = 50000

# Build URL using the Google Maps API and other fields
    target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&radius="+str(radius)+"&type="+target_type
    #target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&rankby=distance"+"&type="+target_type
    #print(target_url)

# Run request
    response = requests.get(target_url)
    city_placestogo = response.json()
   
    if city_placestogo["status"] == "ZERO_RESULTS":
        print(f'{Acty[i].upper()} : No {Acty[i]} near your place of choice.')
        type_of_place.append(target_type)
        place_names.append("Not Available ")
        addresses.append("Not Available ")
        rating.append("Not Available ")
        openorclose.append("Not Available ")
        print("\n")
    else:
        print(f'{Acty[i].upper()} : Bingo!!! We have found good {Acty[i]}s near your place of choice.')
        #print("\n")
        count = 0
        for item in city_placestogo["results"]:
            myplace = item["name"]
            myplace = myplace.replace(" ", "%20")
            target_url = places_url+"key="+gkey+"&input="+myplace+"&inputtype=textquery"+"&fields=formatted_address,name,rating,opening_hours"
            #print(target_url)
            response = requests.get(target_url)
            data = response.json()
            #print(data)
            type_of_place.append(target_type)
            try:
                place_names.append(data["candidates"][0]["name"])
            except:
                place_names.append(item["name"])
            try:    
                addresses.append(data["candidates"][0]["formatted_address"])
            except:
                addresses.append(item["vicinity"])
            try:    
                rating.append(data["candidates"][0]["rating"])
            except:   
                rating.append(np.nan)
            try:  
                if(data["candidates"][0]["opening_hours"]["open_now"]):
                    openorclose_status = "Open"
                else:
                    openorclose_status = "Closed"
                openorclose.append(openorclose_status)
            except:
                openorclose.append("Check the opening hours on the website")
                #print("No or incomplete information found")
            count = count + 1
        print(f'Total {count} {Acty[i]}s are found near {City}')
        print("\n")
# Out:
# BAR : Bingo!!! We have found good bars near your place of choice.
# Total 20 bars are found near East Brunswick
#
#
# CASINO : Bingo!!! We have found good casinos near your place of choice.
# Total 18 casinos are found near East Brunswick
#
#
# LODGING : Bingo!!! We have found good lodgings near your place of choice.
# Total 20 lodgings are found near East Brunswick
#
#
# MOVIE_RENTAL : Bingo!!! We have found good movie_rentals near your place of choice.
# Total 20 movie_rentals are found near East Brunswick
#
#
# MOVIE_THEATER : Bingo!!! We have found good movie_theaters near your place of choice.
# Total 20 movie_theaters are found near East Brunswick
#
#
# NIGHT_CLUB : Bingo!!! We have found good night_clubs near your place of choice.
# Total 20 night_clubs are found near East Brunswick
#
#
# RESTAURANT : Bingo!!! We have found good restaurants near your place of choice.
# Total 20 restaurants are found near East Brunswick

# %%
Df = pd.DataFrame({"Type":type_of_place,"Place":place_names,"Address":addresses, "Rating":rating,
                  "OpenorClose":openorclose})

# %%
Df[["Type","Place","Address","Rating","OpenorClose"]]
Df[Df["Type"] == "movie_theater"]
# Out:
#                                               Address  \
# 78            1021 US-22, Mountainside, NJ 07092, USA
# 79  400 Commons Way Suite 380, Bridgewater, NJ 088...
# 80                 55 Parsonage Road unit 390, Edison
# 81              17 US-1, New Brunswick, NJ 08901, USA
# 82       495 Prospect Ave, West Orange, NJ 07052, USA
# 83              106 Court St, Brooklyn, NY 11201, USA
# 84    325 Sloan Ave, Hamilton Township, NJ 08619, USA
# 85      2474 Forest Ave, Staten Island, NY 10303, USA
# 86  2399 US-1, North Brunswick Township, NJ 08902,...
# 87            1200 S Stiles St, Linden, NJ 07036, USA
# 88           3907 Shore Pkwy, Brooklyn, NY 11235, USA
# 89                               3521 US-1, Princeton
# 90  66 Third Ave (11th St), New York, NY 10003, Un...
# 91             222 Jersey City Boulevard, Jersey City
# 92                   405 NJ-3, Clifton, NJ 07014, USA
# 93         102 North End Ave, New York, NY 10281, USA
# 94          209 W Houston St, New York, NY 10014, USA
# 95          30 Lafayette Ave, Brooklyn, NY 11217, USA
# 96  1000 Corporate Ct, South Plainfield, NJ 07080,...
# 97              890 Broadway, New York, NY 10003, USA
#
#                                OpenorClose  \
# 78  Check the opening hours on the website
# 79  Check the opening hours on the website
# 80  Check the opening hours on the website
# 81  Check the opening hours on the website
# 82  Check the opening hours on the website
# 83                                    Open
# 84  Check the opening hours on the website
# 85                                    Open
# 86                                    Open
# 87  Check the opening hours on the website
# 88                                    Open
# 89  Check the opening hours on the website
# 90  Check the opening hours on the website
# 91  Check the opening hours on the website
# 92  Check the opening hours on the website
# 93                                    Open
# 94  Check the opening hours on the website
# 95  Check the opening hours on the website
# 96                                    Open
# 97  Check the opening hours on the website
#
#                                                 Place  Rating           Type
# 78                                AMC Mountainside 10     4.2  movie_theater
# 79                          AMC DINE-IN Bridgewater 7     3.6  movie_theater
# 80                          AMC DINE-IN Menlo Park 12     NaN  movie_theater
# 81                         AMC Loews New Brunswick 18     4.0  movie_theater
# 82                          AMC DINE-IN Essex Green 9     3.7  movie_theater
# 83               United Artists Court Street 12 & RPX     3.9  movie_theater
# 84                                    AMC Hamilton 24     4.1  movie_theater
# 85              United Artists Staten Island 16 & RPX     4.1  movie_theater
# 86                   Regal Commerce Center Stadium 18     4.4  movie_theater
# 87                                    AMC Aviation 12     4.3  movie_theater
# 88        United Artists Sheepshead Bay 14 IMAX & RPX     4.1  movie_theater
# 89                                  AMC MarketFair 10     NaN  movie_theater
# 90                                      AMC Village 7     4.4  movie_theater
# 91  Jennifer Chalsty Planetarium & LSC Giant Dome ...     NaN  movie_theater
# 92                             AMC Clifton Commons 16     4.1  movie_theater
# 93                      Regal Cinemas Battery Park 11     4.5  movie_theater
# 94                                         Film Forum     4.6  movie_theater
# 95                          Brooklyn Academy of Music     4.6  movie_theater
# 96                    Regal Cinemas Hadley Theatre 16     4.3  movie_theater
# 97                          AMC Loews 19th St. East 6     3.4  movie_theater

# %%
Df.fillna(0, inplace=True)
Df
# for acty in Acty:
#     print(acty.upper())
#     Df = Df[Df["Type"]==acty]
#     print(Df.columns)
#     print("\n")
# print(Df)
# Out:
# Empty DataFrame
# Columns: [Address, OpenorClose, Place, Rating, Type]
# Index: []

# %%
Df.fillna(0, inplace=True)

dict={}

for item in Acty:
    item_Df = Df[Df["Type"]==item].reset_index()
    item_Df = item_Df.drop("index",1)       
    dict[item] = item_Df
    print(type(dict[item]))
    print(dict[item][["Place","Rating"]])
    print(dict[item]["Place"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                      Place  Rating
# 0         The Madison Hotel Morristown, NJ     4.4
# 1                          The Peacock Inn     4.6
# 2                          Texas Roadhouse     0.0
# 3                          Battery Gardens     3.9
# 4                         The Bernards Inn     4.4
# 5                             Extra Virgin     4.2
# 6                       Tick Tock Diner NY     3.6
# 7                              ABC Kitchen     4.4
# 8                          The Mermaid Inn     0.0
# 9                          Flatiron Lounge     4.4
# 10                 Maggiano's Little Italy     0.0
# 11  Chris Michael's Steakhouse & Nightclub     4.0
# 12      Blue Morel Restaurant and Wine Bar     4.1
# 13                         North End Grill     4.4
# 14                        Spot Dessert Bar     4.5
# 15                         Char Steakhouse     0.0
# 16                     David Burke Kitchen     4.3
# 17                     Stoney Brook Grille     4.3
# 18                             Casa Mezcal     4.3
# 19                        Tamarind Tribeca     4.4
# 0           The Madison Hotel Morristown, NJ
# 1                            The Peacock Inn
# 2                            Texas Roadhouse
# 3                            Battery Gardens
# 4                           The Bernards Inn
# 5                               Extra Virgin
# 6                         Tick Tock Diner NY
# 7                                ABC Kitchen
# 8                            The Mermaid Inn
# 9                            Flatiron Lounge
# 10                   Maggiano's Little Italy
# 11    Chris Michael's Steakhouse & Nightclub
# 12        Blue Morel Restaurant and Wine Bar
# 13                           North End Grill
# 14                          Spot Dessert Bar
# 15                           Char Steakhouse
# 16                       David Burke Kitchen
# 17                       Stoney Brook Grille
# 18                               Casa Mezcal
# 19                          Tamarind Tribeca
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                                 Place  Rating
# 0                            Route 22 Limousine Corp.     3.0
# 1                                   Wow Entertainment     0.0
# 2                       Events Plus Entertainment LLC     5.0
# 3                                 ARC Marketing, Inc.     0.0
# 4   Tonz of Fun Entertainment Parties Corporate DJ...     5.0
# 5                                Gaimari Gaming Group     0.0
# 6                      Travel Planners of Chatham LLC     0.0
# 7                              Deal Casino Beach Club     4.6
# 8                                     Hippodrome Live     4.1
# 9                                        Lucky Corner     4.7
# 10                              Caesars World Resorts     3.4
# 11                                      Ocean Lottery     0.0
# 12                               Yardley Travel, LTD.     0.0
# 13                                      Atlantic City     0.0
# 14          Monmouth Park Sports Book by William Hill     0.0
# 15                                      Colonial Deli     0.0
# 16                       Solomon R. Guggenheim Museum     4.3
# 17                                Casino Nights To Go     0.0
# 0                              Route 22 Limousine Corp.
# 1                                     Wow Entertainment
# 2                         Events Plus Entertainment LLC
# 3                                   ARC Marketing, Inc.
# 4     Tonz of Fun Entertainment Parties Corporate DJ...
# 5                                  Gaimari Gaming Group
# 6                        Travel Planners of Chatham LLC
# 7                                Deal Casino Beach Club
# 8                                       Hippodrome Live
# 9                                          Lucky Corner
# 10                                Caesars World Resorts
# 11                                        Ocean Lottery
# 12                                 Yardley Travel, LTD.
# 13                                        Atlantic City
# 14            Monmouth Park Sports Book by William Hill
# 15                                        Colonial Deli
# 16                         Solomon R. Guggenheim Museum
# 17                                  Casino Nights To Go
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                                 Place  Rating
# 0                     Best Western East Brunswick Inn     3.3
# 1   Holiday Inn Express & Suites Tower Center New ...     0.0
# 2   Hilton East Brunswick Hotel & Executive Meetin...     4.0
# 3           Hampton Inn North Brunswick/New Brunswick     4.2
# 4         Howard Johnson Express Inn-New Brunswick NJ     2.3
# 5              The Heldrich Hotel & Conference Center     4.2
# 6                         Hyatt Regency New Brunswick     4.2
# 7                                 Crowne Plaza Edison     3.9
# 8                Sheraton Edison Hotel Raritan Center     3.6
# 9   Knights Inn South Amboy/Garden State Parkway S...     3.3
# 10            Hilton Garden Inn Edison/Raritan Center     4.3
# 11     Courtyard by Marriott Cranbury South Brunswick     4.2
# 12  Fairfield Inn & Suites by Marriott Edison-Sout...     0.0
# 13                                Red Roof Inn Edison     3.3
# 14            Courtyard by Marriott Edison Woodbridge     4.1
# 15                                 Motel 6 Piscataway     3.7
# 16                         The Garden Executive Hotel     3.9
# 17            Hampton Inn South Plainfield-Piscataway     4.4
# 18                 Homewood Suites by Hilton Somerset     4.1
# 19       Embassy Suites by Hilton Piscataway Somerset     4.3
# 0                       Best Western East Brunswick Inn
# 1     Holiday Inn Express & Suites Tower Center New ...
# 2     Hilton East Brunswick Hotel & Executive Meetin...
# 3             Hampton Inn North Brunswick/New Brunswick
# 4           Howard Johnson Express Inn-New Brunswick NJ
# 5                The Heldrich Hotel & Conference Center
# 6                           Hyatt Regency New Brunswick
# 7                                   Crowne Plaza Edison
# 8                  Sheraton Edison Hotel Raritan Center
# 9     Knights Inn South Amboy/Garden State Parkway S...
# 10              Hilton Garden Inn Edison/Raritan Center
# 11       Courtyard by Marriott Cranbury South Brunswick
# 12    Fairfield Inn & Suites by Marriott Edison-Sout...
# 13                                  Red Roof Inn Edison
# 14              Courtyard by Marriott Edison Woodbridge
# 15                                   Motel 6 Piscataway
# 16                           The Garden Executive Hotel
# 17              Hampton Inn South Plainfield-Piscataway
# 18                   Homewood Suites by Hilton Somerset
# 19         Embassy Suites by Hilton Piscataway Somerset
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                            Place  Rating
# 0      Princeton Record Exchange     4.8
# 1                         Redbox     0.0
# 2              Playtime Boutique     3.2
# 3                         Redbox     0.0
# 4         Majors Records & Video     3.9
# 5   Video Network Communications     0.0
# 6               Murder To Go Inc     0.0
# 7          Academy Records & CDs     4.2
# 8                         Redbox     0.0
# 9                         Redbox     0.0
# 10                        Redbox     0.0
# 11                        Redbox     0.0
# 12      Once In A Lifetime Video     0.0
# 13            The Sound Exchange     0.0
# 14                        Redbox     0.0
# 15                        Redbox     0.0
# 16                        Redbox     0.0
# 17                        Redbox     0.0
# 18                        Redbox     0.0
# 19                        Redbox     0.0
# 0        Princeton Record Exchange
# 1                           Redbox
# 2                Playtime Boutique
# 3                           Redbox
# 4           Majors Records & Video
# 5     Video Network Communications
# 6                 Murder To Go Inc
# 7            Academy Records & CDs
# 8                           Redbox
# 9                           Redbox
# 10                          Redbox
# 11                          Redbox
# 12        Once In A Lifetime Video
# 13              The Sound Exchange
# 14                          Redbox
# 15                          Redbox
# 16                          Redbox
# 17                          Redbox
# 18                          Redbox
# 19                          Redbox
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                                 Place  Rating
# 0                                 AMC Mountainside 10     4.2
# 1                           AMC DINE-IN Bridgewater 7     3.6
# 2                           AMC DINE-IN Menlo Park 12     0.0
# 3                          AMC Loews New Brunswick 18     4.0
# 4                           AMC DINE-IN Essex Green 9     3.7
# 5                United Artists Court Street 12 & RPX     3.9
# 6                                     AMC Hamilton 24     4.1
# 7               United Artists Staten Island 16 & RPX     4.1
# 8                    Regal Commerce Center Stadium 18     4.4
# 9                                     AMC Aviation 12     4.3
# 10        United Artists Sheepshead Bay 14 IMAX & RPX     4.1
# 11                                  AMC MarketFair 10     0.0
# 12                                      AMC Village 7     4.4
# 13  Jennifer Chalsty Planetarium & LSC Giant Dome ...     0.0
# 14                             AMC Clifton Commons 16     4.1
# 15                      Regal Cinemas Battery Park 11     4.5
# 16                                         Film Forum     4.6
# 17                          Brooklyn Academy of Music     4.6
# 18                    Regal Cinemas Hadley Theatre 16     4.3
# 19                          AMC Loews 19th St. East 6     3.4
# 0                                   AMC Mountainside 10
# 1                             AMC DINE-IN Bridgewater 7
# 2                             AMC DINE-IN Menlo Park 12
# 3                            AMC Loews New Brunswick 18
# 4                             AMC DINE-IN Essex Green 9
# 5                  United Artists Court Street 12 & RPX
# 6                                       AMC Hamilton 24
# 7                 United Artists Staten Island 16 & RPX
# 8                      Regal Commerce Center Stadium 18
# 9                                       AMC Aviation 12
# 10          United Artists Sheepshead Bay 14 IMAX & RPX
# 11                                    AMC MarketFair 10
# 12                                        AMC Village 7
# 13    Jennifer Chalsty Planetarium & LSC Giant Dome ...
# 14                               AMC Clifton Commons 16
# 15                        Regal Cinemas Battery Park 11
# 16                                           Film Forum
# 17                            Brooklyn Academy of Music
# 18                      Regal Cinemas Hadley Theatre 16
# 19                            AMC Loews 19th St. East 6
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                      Place  Rating
# 0                          Flatiron Lounge     4.4
# 1   Chris Michael's Steakhouse & Nightclub     4.0
# 2                         Tamarind Tribeca     4.4
# 3                                   The DL     3.7
# 4                                    Perle     0.0
# 5                      Five Spot Soul Food     3.5
# 6                                   Pianos     0.0
# 7                                Blue Note     4.3
# 8                               Go-Go Rama     3.9
# 9                   Skylark Diner & Lounge     4.2
# 10                The Cornelia Street Cafe     4.3
# 11                            STK Downtown     4.0
# 12              Stress Factory Comedy Club     4.5
# 13                          Beauty & Essex     0.0
# 14                                   Cielo     0.0
# 15                          The 40/40 Club     0.0
# 16                                  Uproot     4.5
# 17               Grasshopper off the Green     4.2
# 18                           Jazz Standard     4.6
# 19                             Vol de Nuit     4.3
# 0                            Flatiron Lounge
# 1     Chris Michael's Steakhouse & Nightclub
# 2                           Tamarind Tribeca
# 3                                     The DL
# 4                                      Perle
# 5                        Five Spot Soul Food
# 6                                     Pianos
# 7                                  Blue Note
# 8                                 Go-Go Rama
# 9                     Skylark Diner & Lounge
# 10                  The Cornelia Street Cafe
# 11                              STK Downtown
# 12                Stress Factory Comedy Club
# 13                            Beauty & Essex
# 14                                     Cielo
# 15                            The 40/40 Club
# 16                                    Uproot
# 17                 Grasshopper off the Green
# 18                             Jazz Standard
# 19                               Vol de Nuit
# Name: Place, dtype: object
# <class 'pandas.core.frame.DataFrame'>
#                                      Place  Rating
# 0                    The Molly Pitcher Inn     4.3
# 1         The Madison Hotel Morristown, NJ     4.4
# 2                            Olde Mill Inn     4.4
# 3                          The Peacock Inn     4.6
# 4         Sheraton Brooklyn New York Hotel     3.9
# 5                             P.F. Chang's     0.0
# 6                          Texas Roadhouse     0.0
# 7                          Battery Gardens     3.9
# 8                         The Bernards Inn     4.4
# 9                             Extra Virgin     4.2
# 10                      Tick Tock Diner NY     3.6
# 11                   Moe's Southwest Grill     0.0
# 12                             ABC Kitchen     4.4
# 13                         The Mermaid Inn     0.0
# 14                                Maialino     4.4
# 15                 Maggiano's Little Italy     0.0
# 16                           Di Fara Pizza     4.3
# 17  Chris Michael's Steakhouse & Nightclub     4.0
# 18      Blue Morel Restaurant and Wine Bar     4.1
# 19                  Auntie Anne's Pretzels     0.0
# 0                      The Molly Pitcher Inn
# 1           The Madison Hotel Morristown, NJ
# 2                              Olde Mill Inn
# 3                            The Peacock Inn
# 4           Sheraton Brooklyn New York Hotel
# 5                               P.F. Chang's
# 6                            Texas Roadhouse
# 7                            Battery Gardens
# 8                           The Bernards Inn
# 9                               Extra Virgin
# 10                        Tick Tock Diner NY
# 11                     Moe's Southwest Grill
# 12                               ABC Kitchen
# 13                           The Mermaid Inn
# 14                                  Maialino
# 15                   Maggiano's Little Italy
# 16                             Di Fara Pizza
# 17    Chris Michael's Steakhouse & Nightclub
# 18        Blue Morel Restaurant and Wine Bar
# 19                    Auntie Anne's Pretzels
# Name: Place, dtype: object
