# %%
import requests
import json
import time

import pandas as pd
from datetime import timedelta
from datetime import datetime
from config import gkey

# %%
name = "Pragati Soni Mehta"
name = name.replace(" ","%20")
name
# Out:
# 'Pragati%20Soni%20Mehta'

# %%
places_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"
#myplace = "Museum%20of%20Contemporary%20Art%20Australia" 
#myplace = "2%20Colony%20Drive%20East,%20West%20Orange"
myplace = "Skin Deep of Somerville"
myplace = myplace.replace(" ", "%20")
target_url = places_url+"key="+gkey+"&input="+myplace+"&inputtype=textquery"+"&fields=formatted_address,name,rating,opening_hours"
print(target_url)
response = requests.get(target_url)
data = response.json()
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&input=Skin%20Deep%20of%20Somerville&inputtype=textquery&fields=formatted_address,name,rating,opening_hours

# %%
places_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"
#myplace="Absolutely%20Fish"
#myplace = "2%20Colony%20Drive%20East,%20West%20Orange"
myplace = "Skin Deep of Somerville"
myplace = myplace.replace(" ", "%20")
target_url = places_url+"key="+gkey+"&input="+myplace+"&inputtype=textquery"
print(target_url)
response = requests.get(target_url)
data = response.json()
place_id = data["candidates"][0]["place_id"]
#place_id
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&input=Skin%20Deep%20of%20Somerville&inputtype=textquery

# %%
details_url = "https://maps.googleapis.com/maps/api/place/details/json?"
target_url = details_url+"key="+gkey+"&placeid="+place_id
print(target_url)
response = requests.get(target_url)
data = response.json()
# Out:
# https://maps.googleapis.com/maps/api/place/details/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&placeid=ChIJWUjus0uVw4kRRJgCaia4VLA

# %%
print(f'Is it open? {data["result"]["opening_hours"]["open_now"]}')
print(f'Weekly hours of operation: {data["result"]["opening_hours"]["weekday_text"]}')
print(f'Rating: {data["result"]["rating"]}')
# Out:
# Is it open? False
# Weekly hours of operation: ['Monday: 10:00 AM – 7:30 PM', 'Tuesday: 10:00 AM – 7:30 PM', 'Wednesday: 10:00 AM – 7:30 PM', 'Thursday: 10:00 AM – 7:30 PM', 'Friday: 10:00 AM – 7:30 PM', 'Saturday: 10:00 AM – 7:30 PM', 'Sunday: Closed']
# Rating: 5

# %%
#https://developers.google.com/places/web-service/supported_types

#Segregated the places types into indoor and outdoor activities 
Acty_In = pd.read_excel("Resources/Indoor.xlsx")
Acty_Out = pd.read_excel("Resources/Outdoor.xlsx")

#Converting the dataframe into list
Acty_Outlist = Acty_Out["Outdoor"].tolist()
Acty_Inlist = Acty_In["Indoor"].tolist()
   
# Acty_Outlist
# Acty_Inlist

# for i in range(len(Acty_Outlist)):
#     print(Acty_Outlist[i])

# %%
# CurrentTime = datetime.now().time()
# print(CurrentTime)

# ExpectedDate = "12:00"
# ExpectedDate = datetime.strptime(ExpectedDate, "%H:%M")
# print(ExpectedDate)

# # if CurrentDate > ExpectedDate:
# #     print("Date missed")
# # else:
# #     print("Date not missed")

# print(time.ctime())
# time.strptime(time.ctime(),"%a %b %d %H:%M:%S %Y")

# print(datetime.now().time())

# time.strptime(22:28:12.419921,"%H:%M:%S %j")


# CurrentDate = datetime.now()
# print(CurrentDate)
# Midday = to_datetime("12:00:00", format="%H:%M:%S").datetime.time
# print(Midday)

# CurrentTime = datetime.now().time()
# print(CurrentTime)
# print(type(CurrentTime))
# CurrTime = time.ctime()
# print(CurrTime)
# type(CurrTime)

# x = datetime.strptime('12/31/13 12:12', "%m/%j/%y %H:%M").time()
# print(x)
# # if(datetime.time(12,12) > datetime.time(12,00)):
# #     print("good")
#datetime.datetime.time(10, 53)

# %%
# #define the input time string
# input_time_string = '12:00:00'
# time_format_string = '%H:%M:%S'
# print('input time string = {time}'.format(time=input_time_string))

# #create a datetime object initialized to the time provided by the input time
# #string defined above
# datetime_obj = datetime.strptime(input_time_string, time_format_string)
# print(datetime_obj)
# print(type(datetime_obj))
# #format the datetime object as a string containing only the time
# output_time_string = datetime_obj.strftime(time_format_string)
# print(output_time_string)
# print(type(output_time_string))

# #print the time string
# print('output time string = {time}'.format(time=output_time_string))

# CurrentTime = datetime.now().time()
# print(CurrentTime)
# print(type(CurrentTime))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-239-949065ec532b> in <module>()
#      13 # print(output_time_string)
#      14 # print(type(output_time_string))
# ---> 15 output_time_string.to_time()
#      16 # #print the time string
#      17 # print('output time string = {time}'.format(time=output_time_string))
#
# AttributeError: 'str' object has no attribute 'to_time'

# %%
#Input the target city and state
target_city = input("Enter city & state in the format 'city,state: ")
# Out:
# Enter city & state in the format 'city,state: Bridgewater,NJ

# %%
#Creating the params dict with address and key
params = {"address": target_city, "key": gkey}

# %%
# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# %%
# Run request
response = requests.get(base_url, params=params)
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=Bridgewater%2CNJ&key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ

# %%
# Convert the response to JSON
city_geo = response.json()

# Extract Lat/Lng
lat = city_geo["results"][0]["geometry"]["location"]["lat"]
lng = city_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print("%s: %s, %s" % (target_city, lat, lng))

#Converting the lat & lng to string
lat = str(lat)
lng = str(lng)
# Out:
# Bridgewater,NJ: 40.5939636, -74.6049061

# %%
#Google maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# %%
#Find the names and addresses of nearbyplaces in given city,state entered by the user.
#Hint: See https://developers.google.com/places/web-service/supported_types
Acty = input("Enter Outdoor or Indoor: ")
#print(Acty)

if (Acty == "Outdoor"):
    Acty = Acty_Outlist
    print(Acty)
elif (Acty == "Indoor"):
    Acty = Acty_Inlist
    print(Acty)
# Out:
# Enter Outdoor or Indoor: Indoor
# ['aquarium', 'art_gallery', 'bakery', 'bar', 'beauty_salon', 'book_store', 'bowling_alley', 'cafe', 'casino', 'clothing_store', 'convenience_store', 'department_store', 'electronics_store', 'florist', 'furniture_store', 'gym', 'jewelry_store', 'library', 'liquor_store', 'lodging', 'movie_rental', 'movie_theater', 'museum', 'night_club', 'pet_store', 'restaurant', 'shoe_store', 'shopping_mall', 'spa', 'store', 'supermarket']

# %%
for i in range(len(Acty)):
    
    target_type = Acty[i]
    radius = 50000

# Build URL using the Google Maps API
    #target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&radius="+str(radius)+"&type="+target_type#+"&opennow"
    target_url = base_url+"key="+gkey+"&location="+lat+","+lng+"&rankby=distance"+"&type="+target_type#+"&opennow"
    #print(target_url)

# Run request
    response = requests.get(target_url)
    #print(response.url)
    city_placestogo = response.json()

# Print the json (pretty printed)
    #print(json.dumps(city_placestogo, indent=4, sort_keys=True))
    counter = 1
    print(f'The {Acty[i]}s near {target_city}')
    if city_placestogo["status"] == "ZERO_RESULTS":
        print(f'No {Acty[i]} in the vicinity')
    else:
        for item in city_placestogo["results"]:
            print(f'{counter}. {item["name"]}')
            print(f'    {item["vicinity"]}')
            counter = counter+1
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=aquarium
# The aquariums near Bridgewater,NJ
# No aquarium in the vicinity
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=art_gallery
# The art_gallerys near Bridgewater,NJ
# 1. SuHua Low's Art Studio
#     62 Woodlawn Avenue, Bridgewater
# 2. Thomas Kinkade Gallery
#     400 Commons Way, Bridgewater
# 3. Gallery on Main
#     30 West Main Street, Somerville
# 4. Artworks By Marcine
#     Manville
# 5. Printmaking Center of NJ
#     440 River Road, Branchburg
# 6. OfficeClocks
#     42 Old Camplain Road, Hillsborough Township
# 7. The Center for Contemporary Art
#     2020 Burnt Mills Road, Bedminster Township
# 8. Burnt Mills Fine Art and Custom Framing
#     262 U.S. 202, Bedminster Township
# 9. Avila Fine Arts Ltd
#     1850 Burnt Mills Road, Bedminster Township
# 10. Highland Framers
#     1850 Burnt Mills Road, Bedminster Township
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=bakery
# The bakerys near Bridgewater,NJ
# 1. Auntie Anne's
#     400 Commons Way #338, Bridgewater
# 2. Dunkin' Donuts
#     930 U.S. 22, Somerville
# 3. DivaCakes
#     94 West Cliff Street, Somerville
# 4. Somerville Bakery
#     123 West Main Street, Somerville
# 5. Conlin's Cafe & Bakery
#     53 West Main Street, Somerville
# 6. Dunkin' Donuts
#     19 West Main Street, Somerville
# 7. Boulevard 53 LLC
#     53 West Main Street, Somerville
# 8. Blue Sheep Bake Shop
#     9 Division Street, Somerville
# 9. Dessert Plate Bakery
#     34 East Main Street # 1, Somerville
# 10. Bridgewater Bakery
#     150 Adamsville Road North, Bridgewater
# 11. Subway
#     159 North Adamsville Road, Somerville
# 12. Panera Bread
#     300 U.S. 202, Raritan
# 13. Dunkin' Donuts
#     93 U.S. 206, Somerville
# 14. Bagels-4-U OF RARITAN
#     21 U.S. 206, Raritan
# 15. Dewy Meadow Farms
#     1018 Rector Road, Bridgewater
# 16. Dunkin' Donuts
#     1918 Washington Valley Road, Martinsville
# 17. Randazzo Pastry Shop & Bakery
#     611 U.S. 202, Raritan
# 18. Dunkin' Donuts
#     477 Union Avenue, Bridgewater
# 19. Sweet New Creations
#     12 Anderson Street, Raritan
# 20. Italian Bakery
#     64 West Somerset Street # 1, Raritan
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=bar
# The bars near Bridgewater,NJ
# 1. Booker & Zinc
#     700 Commons Way, Bridgewater
# 2. Maggiano's Little Italy
#     600 Commons Way, Bldg E, Bridgewater
# 3. Seasons 52
#     410 Commons Way, Bridgewater
# 4. S.H.E. Bar
#     Bridgewater
# 5. Buffalo Wild Wings
#     970 U.S. 22, Bridgewater
# 6. McCormick & Schmick's Seafood & Steaks
#     400 Commons Way, Bridgewater
# 7. Green Knoll Grille
#     645 U.S. 202, Bridgewater
# 8. Social
#     156 North Gaston Avenue, Somerville
# 9. Red Lobster
#     1271 U.S. 22, Bridgewater
# 10. TGI Fridays
#     395 US Highway 202/206, Bridgewater
# 11. Tapastre
#     1 W High St, Somerville
# 12. Project P.U.B.
#     41 North Bridge Street, Somerville
# 13. The Melting Pot
#     190 West Main Street, Somerville
# 14. The Club House Sports Bar
#     150 West Main Street, Somerville
# 15. Mannion's Pub & Restaurant
#     150 West Main Street, Somerville
# 16. Village Brewing Company
#     34 West Main Street, Somerville
# 17. The Venetian Grille
#     128 West Main Street, Somerville
# 18. Wasabi Asian Plates & Sushi
#     12 Main Street, Somerville
# 19. Alfonso's Trattoria
#     99 West Main Street, Somerville
# 20. McCormick's Pub
#     65 East Main Street, Somerville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=beauty_salon
# The beauty_salons near Bridgewater,NJ
# 1. Shapes Brow Bar
#     400 Commons Way, Bridgewater
# 2. Signature Day Spa
#     400 Commons Way, Bridgewater
# 3. Splash Salon and Spa
#     400 Commons Way, Bridgewater
# 4. Skin-Sation
#     Somerville
# 5. D & D Nails & Spa
#     23 Union Avenue, Somerville
# 6. Hair Studio
#     357 us highway 202-206, Bridgewater
# 7. Bangz Hair & Nail Studio
#     116 North Gaston Avenue, Somerville
# 8. Side Door Hair Salon
#     108 North Gaston Avenue, Somerville
# 9. Ovation Hair Design
#     18 Davenport Street, Somerville
# 10. Merle Norman Cosmetic Studio
#     303 Route 202 206, Bridgewater
# 11. A&T Nail Salon
#     140 West Main Street, Somerville
# 12. Illustrated Beauty
#     120 West Main Street, Somerville
# 13. Belén Nails I Was Ban's Nails
#     90-1 West Main Street, Somerville
# 14. Skin Deep of Somerville
#     52 West Main Street, Somerville
# 15. Saffire Salon
#     2216, 72 West Main Street, Somerville
# 16. Paramount Pampering Salon & Spa
#     56 West Main Street, Somerville
# 17. Capelli Belli Salon
#     215 West Main Street, Somerville
# 18. Lure Lash
#     85 West Main Street, Somerville
# 19. Graceful Beauty Hair Salon
#     29 West Main Street, Somerville
# 20. 75 West Salon Inc
#     75 Main Street, Somerville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=book_store
# The book_stores near Bridgewater,NJ
# 1. Barnes & Noble Booksellers Somerville
#     319 U.S. 206, Bridgewater
# 2. Comic Fortress
#     59 West Main Street, Somerville
# 3. Kavya Inc.
#     17 Campbell Road, Hillsborough Township
# 4. First Internet Med Bookstore
#     60 Huntley Way, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=bowling_alley
# The bowling_alleys near Bridgewater,NJ
# 1. Ten Pin Lanes |
#     1, Rustic Mall, Manville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=cafe
# The cafes near Bridgewater,NJ
# 1. Starbucks
#     400 Mall Commons Way #264, Bridgewater
# 2. Starbucks
#     610 Commons Way #4300, Bridgewater
# 3. Auntie Anne's
#     400 Commons Way #338, Bridgewater
# 4. McDonald's
#     950 Rte 22 East, Somerville
# 5. Dunkin' Donuts
#     930 U.S. 22, Somerville
# 6. Court House Cafe
#     40 North Bridge Street, Somerville
# 7. Tim Hortons
#     223 West End Avenue, Raritan
# 8. Grumpy Bobas
#     72 West Main Street, Somerville
# 9. Phoenix Cafe
#     24 Main Street, Somerville
# 10. Starbucks
#     145 W. Main St, unit A-1, Unit A1, Somerville
# 11. Cafe Picasso
#     81 Main Street #1, Somerville
# 12. Cheech's Own Coffee Company
#     37 West Main Street, Somerville
# 13. Conlin's Cafe & Bakery
#     53 West Main Street, Somerville
# 14. Dunkin' Donuts
#     19 West Main Street, Somerville
# 15. Dragonfly Music and Coffee Cafe
#     14 East Main Street, Somerville
# 16. Subway
#     159 North Adamsville Road, Somerville
# 17. QuickChek
#     361 Union Avenue, Bridgewater
# 18. Panera Bread
#     300 U.S. 202, Raritan
# 19. Dunkin' Donuts
#     93 U.S. 206, Somerville
# 20. Dunkin' Donuts
#     1918 Washington Valley Road, Martinsville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=casino
# The casinos near Bridgewater,NJ
# No casino in the vicinity
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=clothing_store
# The clothing_stores near Bridgewater,NJ
# 1. Maje Corner Bloomingdales Bridgewater
#     410 Commons Way, Bridgewater
# 2. LOFT
#     620 Commons Way, Bridgewater
# 3. T.J. Maxx & HomeGoods
#     300 Commons Way, Bridgewater
# 4. Ted Baker
#     410 Commons Way, Bridgewater
# 5. Coast Fashions US Ltd
#     410 Commons Way, Bridgewater
# 6. Valentine Perfume
#     Bridgewater
# 7. Johnston & Murphy
#     640 Commons Way Suite 4240, Bridgewater
# 8. Bluemercury
#     640 Commons Way, Bridgewater
# 9. Madewell
#     400 Commons Way Space #2395, Bridgewater
# 10. Hollister Co.
#     400 Commons Way #451, Bridgewater
# 11. SKECHERS Retail
#     400 Commons Way #3475, Bridgewater
# 12. Express
#     400 Commons Way, Bridgewater
# 13. UNIQLO Bridgewater Commons
#     400 Commons Way #243, Bridgewater
# 14. abercrombie kids
#     400 Commons Way #253, Bridgewater
# 15. Hobbs
#     410 Commons Way, Bridgewater
# 16. Athleta
#     400 Commons Way, Bridgewater
# 17. Custom Shop Clothiers
#     400 Commons Way, Bridgewater
# 18. Justice
#     400 Commons Way Suite 3420, Bridgewater
# 19. Eddie Bauer
#     400 Commons Way, Bridgewater
# 20. Smalls Formalwear
#     400 Commons Way, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=convenience_store
# The convenience_stores near Bridgewater,NJ
# 1. Stop N Go
#     Bridgewater
# 2. Sunoco Gas Station
#     1062 U.S. 22, Somerville
# 3. 7-Eleven
#     218 Mercer Street, Somerville
# 4. Rite Aid
#     132 North Gaston Avenue, Somerville
# 5. Rite Aid Phamacy
#     132 North Gaston Avenue, Somerville
# 6. Rite Aid
#     353 US Highway 202/206, Bridgewater
# 7. Lucky Spot
#     100 North Gaston Avenue, Somerville
# 8. Downtown News & Tobacco
#     120 West Main Street A, Somerville
# 9. Wald Drug Store
#     40 West Main Street, Somerville
# 10. QuickChek
#     361 Union Avenue, Bridgewater
# 11. Banner Food Store
#     130 East Main Street, Somerville
# 12. Sunoco Gas Station
#     201 East Main Street, Somerville
# 13. Sunoco Gas Station
#     301 Country Club Road, Bridgewater
# 14. Walgreens
#     129 Somerset Street, Somerville
# 15. Mobile Refueling Network
#     77 2nd Street, Somerville
# 16. Krauszer's Food Store
#     1918 Washington Valley Road, Martinsville
# 17. CVS
#     440 Union Avenue, Bridgewater
# 18. Quik Mart Food Store
#     1982 Washington Valley Road, Martinsville
# 19. QuickChek
#     76 West Somerset Street, Raritan
# 20. Stop & Go Food & Video
#     637 East Main Street, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=department_store
# The department_stores near Bridgewater,NJ
# 1. T.J. Maxx & HomeGoods
#     300 Commons Way, Bridgewater
# 2. Bloomingdale's
#     410 Commons Way, Bridgewater
# 3. Sunglass Hut at Macy's
#     400 Commons Way, Bridgewater
# 4. Macy's
#     400 Commons Way, Bridgewater Commons, Bridgewater
# 5. Lord & Taylor
#     400 Commons Way, Bridgewater
# 6. Silk Blossom Corporation
#     953 Papen Road, Bridgewater
# 7. Nordstrom Rack Chimney Rock
#     362 Chimney Rock Road, Bound Brook
# 8. Saks OFF 5TH
#     356 Chimney Rock Road, Bound Brook
# 9. Saks OFF 5TH
#     356 Chimney Rock Road, Bridgewater
# 10. Costco Wholesale
#     325 Promenade Boulevard, Bridgewater
# 11. Marshalls
#     125 Promenade Boulevard, Bridgewater
# 12. Bed Bath & Beyond
#     155 Promenade Boulevard, Bridgewater
# 13. Walmart Pharmacy
#     100 North Main Street, Manville
# 14. Walmart Supercenter
#     100 North Main Street, Manville
# 15. Target
#     200 Promenade Boulevard, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=electronics_store
# The electronics_stores near Bridgewater,NJ
# 1. EasyHandsFree
#     1311 Prince Rodgers Avenue, Bridgewater
# 2. In-Home Piano Lessons
#     50 Prospect Avenue, Bridgewater
# 3. Tilak A Consultant Inc
#     26 Forest Avenue, Bridgewater
# 4. Datanomics Inc
#     991 U.S. 22 #301, Bridgewater
# 5. AirCellCall
#     200 Crestview Road, Bridgewater
# 6. Best Buy
#     300 Commons Way, Bridgewater
# 7. Magnolia Design Center
#     300 Commons Way, Bridgewater
# 8. Pacific Kitchen and Home
#     300 Commons Way, Bridgewater
# 9. Apple Bridgewater
#     400 Commons Way, Bridgewater
# 10. Microsoft
#     400 Commons Way, Bridgewater
# 11. Hot Topic
#     400 Commons Way #3730, Bridgewater
# 12. AT&T Store
#     400 Commons Way #1355, Bridgewater
# 13. Sprint Store
#     400 Commons Way suite 2480, Bridgewater
# 14. T-Mobile
#     400 Commons Way Suite 2045, Bridgewater
# 15. GameStop
#     400 Commons Way, Bridgewater
# 16. Christopher M Vokes
#     Bridgewater
# 17. Swami Ayyappan Systems Corporation
#     Bridgewater
# 18. Devcon Security
#     Somerville
# 19. Leap Systems Inc
#     1170 U.S. 22 #204, Bridgewater
# 20. C-Net
#     1200 U.S. 22, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=florist
# The florists near Bridgewater,NJ
# 1. Edible Arrangements
#     1331 Prince Rodgers Ave, Bridgewater
# 2. Taida Orchids Inc
#     459 Foothill Road, Bridgewater
# 3. Flowers By Heaven Scent LLC
#     96 North Gaston Avenue, Somerville
# 4. House of Blooms
#     13 Davenport Street, Somerville
# 5. Gems & Stems
#     194 West Main Street, Somerville
# 6. Design Studio of Somerville
#     67 West Main Street, Somerville
# 7. Carousel of Flowers
#     15 Main Street, Somerville
# 8. Bountiful Basket
#     US-202 & 2nd Ave, Raritan
# 9. Angelone's Florist
#     101 2nd Avenue, Raritan
# 10. Martinsville Florist
#     1954 Washington Valley Road, Martinsville
# 11. Scott's Florist
#     73 West Somerset Street, Raritan
# 12. America's Florist
#     227 W Union Ave Daily Delivery to Somerville, Bridgewater and Surrounding areas, Bound Brook
# 13. America's Florist
#     227 West Union Avenue, Bound Brook
# 14. America's Florist Inc
#     227 West Union Avenue, Bound Brook
# 15. Stanley's Flowers & Gifts
#     227 West Union Avenue, Bound Brook
# 16. Blooms at the Hills Florist
#     426 U.S. 202 #206, Bedminster Township
# 17. Flowers Ethan
#     201 1/2 East Main Street, Bound Brook
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=furniture_store
# The furniture_stores near Bridgewater,NJ
# 1. Pacific Kitchen and Home
#     300 Commons Way, Bridgewater
# 2. Lovesac
#     400 Commons Way, Bridgewater
# 3. Pottery Barn
#     400 Commons Way #163, Bridgewater
# 4. Yogibo Bean Bags
#     400 Commons Way, Bridgewater
# 5. Williams-Sonoma
#     400 Commons Way Ste 147, Bridgewater
# 6. Sleep Number
#     400 Commons Way Suite 1053, Bridgewater
# 7. Macy's
#     400 Commons Way, Bridgewater Commons, Bridgewater
# 8. Crate and Barrel
#     630 Commons Way, Bridgewater
# 9. Mattress Firm Somerville
#     928 U.S. 22, Somerville
# 10. Ethan Allen
#     870 Route 22, Somerville
# 11. Amundsen Construction
#     Bridgewater
# 12. Peroni's Upholstery
#     Somerville
# 13. A&M Cabinets Design
#     1200 U.S. 22, Bridgewater
# 14. Pier 1 Imports
#     385 U S Hwy 202-206, Bridgewater
# 15. Christmas Tree Shops
#     365 U.S. 202 / 206, Bridgewater
# 16. buybuy BABY
#     711 New Jersey 28, Bridgewater
# 17. Stickley Audi & Co
#     130 West Main Street, Somerville
# 18. Gallery on Main
#     30 West Main Street, Somerville
# 19. Platinum Designs, LLC
#     87 West Main Street, Somerville
# 20. Alpine Flooring
#     57 West Main Street, Somerville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=gym
# The gyms near Bridgewater,NJ
# 1. Curves
#     1321 Prince Rodgers Avenue, Bridgewater
# 2. On Fire 4 Fitness
#     1325 Prince Rodgers Avenue, Bridgewater
# 3. On Fire 4 Fitness, LLC
#     1329 Prince Rodgers Avenue, Bridgewater
# 4. The Little Gym of Bridgewater
#     1335 Prince Rodgers Avenue, Bridgewater
# 5. Freedom Martial Arts
#     1337 Prince Rodgers Avenue, Bridgewater
# 6. lululemon
#     400 Commons Way, Bridgewater
# 7. Nueats International Inc
#     886 U.S. 22, Somerville
# 8. Somerville YMCA
#     2 Green Street, Somerville
# 9. Bridgewater Tennis and Golf
#     537-543 Garretson Road, Bridgewater
# 10. Washington Valley Resevior
#     766 Newmans Lane, Martinsville
# 11. The ZOO Health Club
#     345B, U.S. 202 #206, Bridgewater
# 12. Fortitude Fitness
#     201 West End Avenue, Raritan
# 13. bodhi. by Anthony Monetti
#     198, 198 West Main Street, Somerville
# 14. CrossFit Fort Raritan
#     1329, 201 West End Avenue, Raritan
# 15. FreedOM Yoga Studio
#     34 West Main Street #353, Somerville
# 16. Studio Barre Somerville
#     8 West Main Street, Somerville
# 17. Tatyana's Fitness
#     14 East Main Street, Somerville
# 18. Garden State Adventure Boot Camp
#     775 Talamini Road, Bridgewater
# 19. Strength and Honor Fitness
#     34 East Main Street, Somerville
# 20. Optimum Health and Exercise Therapy
#     256 East Main Street, Somerville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=jewelry_store
# The jewelry_stores near Bridgewater,NJ
# 1. SuHua Low's Art Studio
#     62 Woodlawn Avenue, Bridgewater
# 2. Roman Jewelers
#     500 Commons Way, Bridgewater
# 3. LOFT
#     620 Commons Way, Bridgewater
# 4. T.J. Maxx & HomeGoods
#     300 Commons Way, Bridgewater
# 5. A 4 Fashions Inc
#     400 Commons Way, Bridgewater
# 6. Dora Retail LLC
#     400 Commons Way, Bridgewater
# 7. Bloomingdale's
#     410 Commons Way, Bridgewater
# 8. Soft Surroundings
#     400 Commons Way, Bridgewater
# 9. francesca's
#     400 Bridgewater Commons, 250, Bridgewater
# 10. Kay Jewelers
#     400 Commons Way Unit 314, Bridgewater
# 11. American Coins and Gold
#     400 Commons Way #3305, Bridgewater
# 12. ALEX AND ANI
#     400 Commons Way, Bridgewater
# 13. PANDORA Jewelry
#     400 Commons Way Space 1075 #1075, Bridgewater
# 14. Michael Kors
#     400 Commons Way Suite 228, Bridgewater
# 15. Brighton Collectibles
#     400 Commons Way, Bridgewater
# 16. Forever 21
#     400 Commons Way #310, Bridgewater
# 17. Swarovski Bridgewater Commons
#     400 Commons Way, Bridgewater
# 18. Littman Jewelers
#     400 Commons Way, Bridgewater
# 19. Zales
#     400 Commons Way, Bridgewater
# 20. Claire's
#     400 Commons Way #3025, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=library
# The librarys near Bridgewater,NJ
# 1. Somerset County Library System of New Jersey
#     1 Vogt Drive, Bridgewater
# 2. Mary Jacob's Library
#     Library System of New Jersey,, 1 Vogt Drive, Bridgewater
# 3. Christopher & Dana Reeves
#     Bridgewater
# 4. Somerset County Law Library
#     20 North Bridge Street, Somerville
# 5. Somerville Public Library
#     35 West End Avenue, Somerville
# 6. Raritan Public Library
#     54 East Somerset Street, Raritan
# 7. Biblioteca de Raritan
#     41 Glaser Avenue, Raritan
# 8. Washington Valley Library
#     Washington Valley Road, Martinsville
# 9. Somerset County Historical Society
#     9 Van Veghten Drive, Bridgewater
# 10. SCLSNJ's Manville Library Branch
#     100 South 10th Avenue, Manville
# 11. Surviving Cancer: Our Voices and Choices
#     377 River Road, Branchburg
# 12. Bound Brook Public Library
#     402 East High Street, Bound Brook
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=liquor_store
# The liquor_stores near Bridgewater,NJ
# 1. Old York Cellars
#     400 Commons Way, Bridgewater
# 2. Super Saver
#     888 U.S. 22, Somerville
# 3. Liquor Saver
#     29 Union Avenue, Somerville
# 4. Discover Wine
#     66 West Main Street, Somerville
# 5. Path Liquors and fine wine
#     79 West Main Street, Somerville
# 6. VintEdge Wine & Spirits
#     115 West Main Street, Somerville
# 7. Boro Liquor
#     23 U.S. 206, Raritan
# 8. Raritan Valley Liquor Store
#     3 U.S. 206, Raritan
# 9. Raritan Valley Liquors
#     3 U.S. 206, Raritan
# 10. Kindred Spirits
#     17 East Somerset Street, Raritan
# 11. BUY BEST WINES and LIQUORS
#     477 Union Avenue, Bridgewater
# 12. Spirits of the Valley
#     1990 Washington Valley Road, Martinsville
# 13. Liquor Saver
#     76 West Somerset Street, Raritan
# 14. Liquor Barn
#     1007 Old York Road, Raritan
# 15. Wine Country
#     601 Union Avenue # 2, Bound Brook
# 16. Northside Lounge
#     100 Brooks Boulevard, Manville
# 17. Federal Wine & Liquors
#     505 Westgate Drive, Basking Ridge
# 18. Cyburt's Liquors
#     26 South Main Street, Manville
# 19. Jersey National Capital Wine
#     505 Martinsville Rd, Basking Ridge
# 20. Wegmans Wine, Liquor & Beer
#     724 U.S. 202, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=lodging
# The lodgings near Bridgewater,NJ
# 1. Bridgewater Marriott
#     700 Commons Way, Bridgewater
# 2. Huffington Post On Foothill Road
#     634 Foothill Road, Bridgewater
# 3. Lakeside Estates Inc
#     643 Foothill Road, Bridgewater
# 4. Huffington Post
#     645 Foothill Road, Bridgewater
# 5. Americas Best Value Inn Bridgewater
#     1271 Route 22 West, Bridgewater
# 6. red mill inn
#     North Middaugh Street, Somerville
# 7. Hampton Inn & Suites Bridgewater
#     1277 Route 22 West, Bridgewater
# 8. Somerset Hotel
#     65 East Main Street, Somerville
# 9. Chelsea House
#     350 East Main Street, Somerville
# 10. Hyatt House Bridgewater
#     530 U.S. 22, Bridgewater
# 11. CitiPark
#     792 Chimney Rock Road, Martinsville
# 12. Spavia Day Spa - Chimney Rock
#     325 Chimney Rock Road, Bridgewater
# 13. Four Seasons at Bridgewater.
#     40°37'49. 74°37'56., 3 7th Avenue, Bridgewater
# 14. Hilton Garden Inn Bridgewater
#     500 Promenade Boulevard, Bridgewater
# 15. Manville-Hillsborough Elks #2119
#     1500 Brooks Boulevard, Manville
# 16. North Branch Greenway Park
#     Milltown Road, Bridgewater
# 17. Days Inn by Wyndham Hillsborough
#     118 U.S. 206, Hillsborough Township
# 18. Lariton Nightclub
#     220 South Main Street, Manville
# 19. Sky Farm Inc
#     2916, 177 Allen Road, Basking Ridge
# 20. Courtyard by Marriott Basking Ridge
#     595 Martinsville Road, Basking Ridge
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=movie_rental
# The movie_rentals near Bridgewater,NJ
# 1. The Sound Exchange
#     2216, 76 West Main Street, Somerville
# 2. Redbox
#     1 Davenport Street, Somerville
# 3. Redbox
#     611 West Union Avenue, Bound Brook
# 4. Redbox
#     100 North Main Street, Manville
# 5. Redbox
#     724 U.S. 202, Bridgewater
# 6. Redbox
#     545 Martinsville Road, Basking Ridge
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=movie_theater
# The movie_theaters near Bridgewater,NJ
# 1. AMC DINE-IN Bridgewater 7
#     400 Commons Way Suite 380, Bridgewater
# 2. Reading Cinemas Manville with TITAN LUXE
#     180 North Main Street, Manville
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=museum
# The museums near Bridgewater,NJ
# 1. Exempt Fireman Museum
#     23 North Doughty Avenue, Somerville
# 2. Firehouse Museum
#     15 North Doughty Avenue, Somerville
# 3. Daniel Robert Mansion
#     25 West End Avenue, Somerville
# 4. Wallace House & Old Dutch Parsonage Historic Site
#     71 Somerset Street, Somerville
# 5. Wallace House and Old Dutch Parsonage
#     71 Somerset Street, Somerville
# 6. Children's Museum
#     120 Finderne Avenue # 113, Bridgewater
# 7. Derrick Van Veghten House
#     9 Van Veghten Drive, Bridgewater
# 8. Eagles Nest Museum
#     Miller Lane, Martinsville
# 9. Sanofi Bldg A
#     Sanofi Building D, 55 Corporate Drive, Bridgewater
# 10. Mount "L"
#     07059, Warren
# 11. Bazooka Jeffs Bat Cave
#     241 South 18th Avenue, Manville
# 12. museum
#     92-98 Liberty Ridge Road, Basking Ridge
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=night_club
# The night_clubs near Bridgewater,NJ
# 1. Social
#     156 North Gaston Avenue, Somerville
# 2. Tapastre
#     1 W High St, Somerville
# 3. 1933 Room
#     18 East Main Street, Second Floor, Somerville
# 4. Verve Restaurant
#     18 East Main Street, Somerville
# 5. SayachakStudio
#     301 English Court, Bridgewater
# 6. Fac
#     2 Boyle Place, Bridgewater
# 7. La Cascada Lounge
#     500 West Camplain Road, Manville
# 8. The Westbrook
#     525 Talmage Avenue, Bound Brook
# 9. Bazooka Jeffs Bat Cave
#     241 South 18th Avenue, Manville
# 10. Imperial
#     200 Talmage Avenue, Bound Brook
# 11. Hooters of Somerset
#     60 Cottontail Lane, Somerset
# 12. All Children's Art Center of NJ
#     15 John Street, Bound Brook
# 13. Ovations
#     295 Canal Road, South Bound Brook
# 14. Sanabel
#     Garcia Lane, Somerset
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=pet_store
# The pet_stores near Bridgewater,NJ
# 1. Coral Sea Fish and Pets
#     118 North Gaston Avenue, Somerville
# 2. The Hungry Hound
#     94 West Main Street, Somerville
# 3. Raritan Agway
#     77 Thompson Street, Raritan
# 4. Woof Gang Bakery & Grooming Bridgewater
#     732 U.S. 202 #130, Bridgewater
# 5. loving care pet rescue
#     733 Manville Avenue, Manville
# 6. Love Your Pet LLC
#     110 Onka Street, Manville
# 7. Daisy Garden Center & Sculpture
#     183 U.S. 206, Hillsborough Township
# 8. Fitz's Fish Ponds
#     1921 U.S. 22, Bound Brook
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=restaurant
# The restaurants near Bridgewater,NJ
# 1. Bombay to Kabul
#     1303 Prince Rodgers Avenue, Bridgewater
# 2. Bombay to Kabul
#     1303 Prince Rodgers Avenue, Bridgewater
# 3. Sushi House Inc
#     1339 Prince Rodgers Avenue, Bridgewater
# 4. Thai Kitchen
#     1351 Prince Rogders Ave, Bridgewater Township, NJ 08807, Bridgewater
# 5. Frattellos Ristorante & Pizzeria
#     1357 Prince Rodgers Avenue, Bridgewater
# 6. Booker & Zinc
#     700 Commons Way, Bridgewater
# 7. Maggiano's Little Italy
#     600 Commons Way, Bldg E, Bridgewater
# 8. Seasons 52
#     410 Commons Way, Bridgewater
# 9. The Cheesecake Factory
#     400 Commons Way, Bridgewater
# 10. Chipotle Mexican Grill
#     640 Commons Way suite 4280, Bridgewater
# 11. Shake Shack
#     610 Commons Way #4320, Bridgewater
# 12. Buffalo Wild Wings
#     970 U.S. 22, Bridgewater
# 13. 1000 Degrees Pizza Salad Wings
#     640 Commons Way #4282, Bridgewater
# 14. Master Wok
#     Bridgewater Commons Mall, Bridgewater
# 15. Yong Kang Street Dumpling
#     2806, 610-640 Commons Way, Bridgewater
# 16. McCormick & Schmick's Seafood & Steaks
#     400 Commons Way, Bridgewater
# 17. Charleys Philly Steaks
#     400 Commons Way Spc 3505, Bridgewater
# 18. Saladworks
#     400 Commons Way, Bridgewater
# 19. Baja B Que
#     400 Commons Way, Bridgewater
# 20. Empanada Guy
#     Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=shoe_store
# The shoe_stores near Bridgewater,NJ
# 1. LOFT
#     620 Commons Way, Bridgewater
# 2. Johnston & Murphy
#     640 Commons Way Suite 4240, Bridgewater
# 3. DSW Designer Shoe Warehouse
#     300 Commons Way, Bridgewater
# 4. Hollister Co.
#     400 Commons Way #451, Bridgewater
# 5. SKECHERS Retail
#     400 Commons Way #3475, Bridgewater
# 6. abercrombie kids
#     400 Commons Way #253, Bridgewater
# 7. Eddie Bauer
#     400 Commons Way, Bridgewater
# 8. Vans
#     400 Commons Way #248, Bridgewater
# 9. GUESS
#     400 Commons Way, Space 264, Bridgewater
# 10. Champs Sports
#     400 Commons Way, Bridgewater
# 11. Talbots
#     400 Commons Way, Bridgewater
# 12. lululemon
#     400 Commons Way, Bridgewater
# 13. Aldo
#     400 Commons Way #2390, Bridgewater
# 14. Bloomingdale's
#     410 Commons Way, Bridgewater
# 15. AllSaints
#     410 Commons Way, Bridgewater
# 16. Banana Republic
#     640 Commons Way, Bridgewater
# 17. francesca's
#     400 Bridgewater Commons, 250, Bridgewater
# 18. Journeys
#     400 Commons Way, Bridgewater
# 19. Payless
#     400 Commons Way #189, Bridgewater
# 20. Foot Locker
#     400 Commons Way, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=shopping_mall
# The shopping_malls near Bridgewater,NJ
# 1. Bridgewater Commons
#     400 Commons Way, Bridgewater
# 2. Sunglass Hut
#     400 Commons Way #257, Bridgewater
# 3. Sunglass Hut at Macy's
#     400 Commons Way, Bridgewater
# 4. Lenscrafters at Macy's
#     Bridgewater
# 5. Office
#     365 U.S. 206, Bridgewater
# 6. Somerset Shopping Center
#     395 U.S. 202, Bridgewater
# 7. Ralph Michael Beiran Associates
#     305 Broadway, New York
# 8. Somerville Circle Shopping Center
#     451 New Jersey 28, Raritan
# 9. Raritan Mall
#     166 Orlando Drive, Raritan
# 10. European Wax Center
#     329 Chimney Rock Road, Bound Brook
# 11. Chimney Rock Shopping Center
#     325 Chimney Rock Road, Bridgewater
# 12. Chimney Rock
#     319 Chimney Rock Road, Bridgewater
# 13. Promenade
#     119 Promenade Boulevard, Bridgewater
# 14. Marketplace At Manville
#     North Main Street, Manville
# 15. Bridgewater Towne Center
#     726 U.S. 202, Bridgewater
# 16. Somerset Hills Shopping Center
#     766 U.S. 206, Bridgewater
# 17. Highland Village Center
#     546 Allen Road, Basking Ridge
# 18. Riverwalk Village
#     665 Martinsville Rd, Basking Ridge
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=spa
# The spas near Bridgewater,NJ
# 1. Hekang Health Center
#     1311 Prince Rodgers Avenue, Bridgewater
# 2. Great Lengths Salon & Spa
#     1325 Prince Rodgers Avenue, Bridgewater
# 3. Bluemercury
#     640 Commons Way, Bridgewater
# 4. Signature Day Spa
#     400 Commons Way, Bridgewater
# 5. Splash Salon and Spa
#     400 Commons Way, Bridgewater
# 6. D & D Nails & Spa
#     23 Union Avenue, Somerville
# 7. SOMERVILLE HEALTH SPA
#     26 Davenport Street, Somerville
# 8. Deep Blue Day Spa
#     18 Davenport Street, Somerville
# 9. Paramount Pampering Salon & Spa
#     56 West Main Street, Somerville
# 10. Sunrise Massage Therapy
#     75 West Main Street Suite B, Somerville
# 11. Foot Spa
#     154 Adamsville Road North, Bridgewater
# 12. Appearance Plus
#     11 Monroe Street, Somerville
# 13. Hand Healing Massage Spa
#     114 Thompson Street, Raritan
# 14. Retro Fitness
#     45 U.S. 206, Raritan
# 15. Dr. Mark Karolak, DO, FAOCO - Board Certified Facial Plastic Surgeon
#     1924 Washington Valley Road, Martinsville
# 16. Reflections Center for Skin & Body
#     1924 Washington Valley Road, Martinsville
# 17. Dr. Mitchell C. Chasin, MD
#     1924 Washington Valley Road, Martinsville
# 18. FOX Chase Spa
#     1938 Washington Valley Road, Martinsville
# 19. Pop Girl Spa
#     1958 Washington Valley Road, Martinsville
# 20. GEL and SPA Salon
#     475 Union Avenue, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=store
# The stores near Bridgewater,NJ
# 1. Appliance Repair Bridgewater
#     575 North Bridge Street #4, Bridgewater
# 2. Dirt Doctors/Thiry Brothers home improvements
#     598 North Bridge Street, Bridgewater
# 3. Bagelsmith Food Store & Deli
#     1330 Prince Rodgers Avenue, Bridgewater
# 4. SuHua Low's Art Studio
#     62 Woodlawn Avenue, Bridgewater
# 5. Rahi Stores
#     1302 Prince Rodgers Avenue, Bridgewater
# 6. EasyHandsFree
#     1311 Prince Rodgers Avenue, Bridgewater
# 7. Edible Arrangements
#     1331 Prince Rodgers Ave, Bridgewater
# 8. Sunrise Surprises Llc
#     489 Knollwood Drive, Bridgewater
# 9. Bridgewater Rita's
#     1359 Prince Rodgers Ave, Bridgewater
# 10. In-Home Piano Lessons
#     50 Prospect Avenue, Bridgewater
# 11. Tilak A Consultant Inc
#     26 Forest Avenue, Bridgewater
# 12. Quality Lab Accessories
#     38 Forest Avenue, Bridgewater
# 13. Toys & Things LLC
#     348 Greenfield Road, Bridgewater
# 14. Pfizer Inc
#     400 Crossing Boulevard, Bridgewater
# 15. CASH FOR CARS
#     2nd Fl, 400 Crossing Boulevard, Bridgewater
# 16. Roman Jewelers
#     500 Commons Way, Bridgewater
# 17. Datanomics Inc
#     991 U.S. 22 #301, Bridgewater
# 18. Canaan Media LLC
#     991 U.S. 22, Bridgewater
# 19. AirCellCall
#     200 Crestview Road, Bridgewater
# 20. Taida Orchids Inc
#     459 Foothill Road, Bridgewater
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC5rGYUddVUFDYwhmshYciMpNeQxpa2YmQ&location=40.5939636,-74.6049061&rankby=distance&type=supermarket
# The supermarkets near Bridgewater,NJ
# 1. Twin City Supermarket
#     617 East Main Street, Bridgewater
# 2. Whole Foods Market
#     319 Chimney Rock Road, Bound Brook
# 3. Walmart Supercenter
#     100 North Main Street, Manville
# 4. pizza bros and market
#     Bridgewater
# 5. Wegmans
#     724 U.S. 202, Bridgewater
# 6. The Fresh Market
#     75 Washington Valley Road, Bedminster Township
# 7. Kings Food Markets
#     450 U.S. 202, Bedminster Township
